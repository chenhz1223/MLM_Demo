# %%
using MatrixLMnet
using DataFrames
using Random
using StatsModels
using Plots
Random.seed!(120)
# Out:
# TaskLocalRNG()

# %% [markdown]
# ## Overview
#
# MatrixLMnet is a package for L1 and L2 penalized estimation of matrix linear models; A fast, general methods for fitting sparse matrix linear models to structured high-throughput data. In this demo, we will learn to use this package by a simple simulation study.

# %% [markdown]
# ## Data Generation

# %% [markdown]
# First, construct a `RawData` object consisting of the response variable `Y` and row/column covariates `X` and `Z`. All three matrices must be passed in as 2-dimensional arrays. Note that the `contr` function can be used to set up treatment and/or sum contrasts for categorical variables stored in a DataFrame. By default, `contr` generates treatment contrasts for all specified categorical variables ("treat"). Other options include `"sum"` for sum contrasts, `"noint"` for treatment contrasts with no intercept, and `"sumnoint"` for sum contrasts with no intercept.

# %%
# Dimensions of matrices 
n = 100
m = 250
# Number of column covariates
q = 20

# Generate data with two categorical variables and 4 numerical variables.
X_df = hcat(DataFrame(catvar1=rand(1:5, n), catvar2=rand(["A", "B", "C"], n)), DataFrame(rand(n,4),:auto))

# Convert dataframe to predicton matrix
X = Matrix(contr(X_df, [:catvar1, :catvar2], ["treat", "sum"]))

#X = design_matrix(@mlmFormula(catvar1 + catvar2 + x1 + x2 + x3 + x4), X_df, [(:catvar1, )])

p = size(X)[2]
# Out:
# 10

# %%
Z = rand(m,q)
B = rand(-5:5,p,q)
E = randn(n,m)
Y = X*B*transpose(Z)+E

# Construct a RawData object
dat = RawData(Response(Y), Predictors(X, Z))
# Out:
# RawData(Response([-19.491660660714384 -11.599246293938792 … -9.846025890509917 -3.910552342504766; 1.6869050129842436 15.809262625546225 … 16.77316280061852 27.19168838618037; … ; -36.871293059346954 -45.445727213984966 … -25.67130221861735 -35.67748199691569; 34.25129202722653 28.917993558825945 … 22.068755759265283 6.449966296553046]), Predictors([0.0 0.0 … 0.7629354798627414 0.6997729240121372; 1.0 0.0 … 0.0683641291444198 0.13975716342002353; … ; 0.0 0.0 … 0.8916305292309327 0.6631051207998134; 0.0 0.0 … 0.9728491655926802 0.4753251921489988], [0.21736110326399694 0.9680284954520674 … 0.8414451324120746 0.16389350803169955; 0.4533491360031554 0.9653047071200448 … 0.6532052569477869 0.2122431874934696; … ; 0.17491325894688858 0.221650638553477 … 0.47280492128347373 0.8279142008963407; 0.025477967039622795 0.5373624856736039 … 0.5306255198534721 0.9982313780729508], false, false), 100, 250, 10, 20)

# %% [markdown]
# Create a 1d array of lambda penalties values to fit the estimates. If the lambdas are not in descending order, they will be automatically sorted by `mlmnet`.

# %%
lambdas = reverse(1.8.^(1:10))
# Out:
# 10-element Vector{Float64}:
#  357.0467226624001
#  198.35929036800005
#  110.19960576000003
#   61.22200320000001
#   34.012224
#   18.895680000000002
#   10.4976
#    5.832000000000001
#    3.24
#    1.8

# %% [markdown]
# Create a 1d array of alpha parameter penalties values that determine the penalties mix between L<sub>1</sub> and L<sub>2</sub> to fit the estimates according to the Elastic Net penalization method.  In the case of Lasso regression (L<sub>1</sub> regularization), alpha should be 1, and 0 for Ridge regression (L<sub>2</sub> regularization). If the alphas are not in descending order, they will be automatically sorted by `mlmnet`.

# %%
alphas = reverse(collect(0:0.1:1))
# Out:
# 11-element Vector{Float64}:
#  1.0
#  0.9
#  0.8
#  0.7
#  0.6
#  0.5
#  0.4
#  0.3
#  0.2
#  0.1
#  0.0

# %% [markdown]
# L<sub>1</sub> and L<sub>2</sub>-penalized estimates for matrix linear models can be obtained by running `mlmnet`. In addition to the `RawData` object, `lambdas` and `alphas`, `mlmnet` requires as a keyword argument the function name for an algorithm used to fit Elastic Net penalized estimates. Current methods are: `"cd"` (coordinate descent), `"cd_active"` (active coordinate descent), `"ista"` (ISTA with fixed step size), `"fista"` (FISTA with fixed step size), `"fista_bt"` (FISTA with backtracking), and `"admm"` (ADMM).
#
# An object of type `Mlmnet` will be returned, with variables for the penalized coefficient estimates (`B`) along with the lambda and alpha penalty values used (`lambdas`, `alphas`). By default, `mlmnet` estimates both row and column main effects (X and Z intercepts), but this behavior can be suppressed by setting `hasXIntercept=false` and/or `hasZIntercept=false`; the intercepts will be regularized unless `toXInterceptReg=false` and/or `toZInterceptReg=false`. Individual `X` (row) and `Z` (column) effects can be left unregularized by manually passing in 1d boolean arrays of length `p` and `q` to indicate which effects should be regularized (`true`) or not (`false`) into `toXReg` and `toZReg`. By default, `mlmnet` centers and normalizes the columns of `X` and `Z` to have mean 0 and norm 1 (`toNormalize=true`). Additional keyword arguments include `isVerbose`, which controls message printing; `thresh`, the threshold at which the coefficients are considered to have converged; and `maxiter`, the maximum number of iterations.

# %%
est = mlmnet(dat, lambdas, alphas; method = "admm")
# Out:
# Criterion: 19.184826606351727
# Number of iterations: 16
# Criterion: 247.5541389838715
# Number of iterations: 40
# Criterion: 472.28160566570335
# Number of iterations: 37
# Criterion: 638.5915230212398
# Number of iterations: 43
# Criterion: 671.2990866722264
# Number of iterations: 51
# Criterion: 540.8364818964126
# Number of iterations: 35
# Criterion: 369.674759526384
# Number of iterations: 34
# Criterion: 232.29710840917514
# Number of iterations: 21
# Criterion: 138.68623212253885
# Number of iterations: 32
# Criterion: 80.50308000596563
# Number of iterations: 20
# Criterion: 19.18482660756022
# Number of iterations: 13
# Criterion: 46.36094706718012
# Number of iterations: 36
# Criterion: 114.86068039304456
# Number of iterations: 39
# Criterion: 242.0544810377271
# Number of iterations: 37
# Criterion: 395.2786268995153
# Number of iterations: 35
# Criterion: 509.68756204105665
# Number of iterations: 34
# Criterion: 547.6205866746141
# Number of iterations: 26
# Criterion: 501.64364080134715
# Number of iterations: 19
# Criterion: 402.9180227705461
# Number of iterations: 28
# Criterion: 290.9910708060342
# Number of iterations: 17
# Criterion: 19.642641237236692
# Number of iterations: 24
# Criterion: 37.63018574667204
# Number of iterations: 26
# Criterion: 77.72225439934097
# Number of iterations: 28
# Criterion: 158.176335250168
# Number of iterations: 39
# Criterion: 270.98953821442274
# Number of iterations: 37
# Criterion: 389.95222895227016
# Number of iterations: 35
# Criterion: 481.12341249633937
# Number of iterations: 31
# Criterion: 512.461127539455
# Number of iterations: 27
# Criterion: 473.94165918269823
# Number of iterations: 28
# Criterion: 386.11835629020254
# Number of iterations: 28
# Criterion: 20.03333191697994
# Number of iterations: 24
# Criterion: 34.33011969147016
# Number of iterations: 27
# Criterion: 64.08920561236
# Number of iterations: 31
# Criterion: 122.97415970659785
# Number of iterations: 39
# Criterion: 209.73400220434323
# Number of iterations: 37
# Criterion: 314.6777784334074
# Number of iterations: 43
# Criterion: 417.2781250684312
# Number of iterations: 35
# Criterion: 485.60038510592614
# Number of iterations: 32
# Criterion: 491.71170805773664
# Number of iterations: 29
# Criterion: 435.56548116843834
# Number of iterations: 27
# Criterion: 21.15929462750094
# Number of iterations: 24
# Criterion: 32.483583788515915
# Number of iterations: 24
# Criterion: 57.2379442978778
# Number of iterations: 35
# Criterion: 103.51775929931043
# Number of iterations: 35
# Criterion: 173.2123707533211
# Number of iterations: 40
# Criterion: 264.48283160502785
# Number of iterations: 39
# Criterion: 366.47603033089763
# Number of iterations: 37
# Criterion: 452.303499543882
# Number of iterations: 34
# Criterion: 488.9467481320515
# Number of iterations: 29
# Criterion: 461.3991086487082
# Number of iterations: 27
# Criterion: 22.477992004545026
# Number of iterations: 26
# Criterion: 31.851703513141317
# Number of iterations: 26
# Criterion: 53.32988786248586
# Number of iterations: 34
# Criterion: 91.14212610121186
# Number of iterations: 41
# Criterion: 148.8120510196581
# Number of iterations: 40
# Criterion: 228.80192812760828
# Number of iterations: 44
# Criterion: 326.224213950386
# Number of iterations: 39
# Criterion: 420.02537243500075
# Number of iterations: 32
# Criterion: 477.36228975830716
# Number of iterations: 31
# Criterion: 473.81222348925934
# Number of iterations: 28
# Criterion: 23.360258624606573
# Number of iterations: 25
# Criterion: 32.05667744276938
# Number of iterations: 31
# Criterion: 50.727632832039475
# Number of iterations: 40
# Criterion: 82.38123387060645
# Number of iterations: 39
# Criterion: 131.2810696976901
# Number of iterations: 41
# Criterion: 202.1668170461234
# Number of iterations: 40
# Criterion: 293.89836536952726
# Number of iterations: 40
# Criterion: 390.6896611357346
# Number of iterations: 34
# Criterion: 462.0045072506229
# Number of iterations: 33
# Criterion: 478.2135527216117
# Number of iterations: 22
# Criterion: 23.934239660037832
# Number of iterations: 37
# Criterion: 32.562407304856364
# Number of iterations: 39
# Criterion: 48.787845046538244
# Number of iterations: 42
# Criterion: 75.63286339992493
# Number of iterations: 41
# Criterion: 117.9490499357577
# Number of iterations: 41
# Criterion: 181.49184827467687
# Number of iterations: 40
# Criterion: 267.4871315378285
# Number of iterations: 42
# Criterion: 364.5444634433177
# Number of iterations: 36
# Criterion: 445.27503591381867
# Number of iterations: 34
# Criterion: 477.51727811542537
# Number of iterations: 27
# Criterion: 25.04805207361256
# Number of iterations: 34
# Criterion: 33.12651761765258
# Number of iterations: 46
# Criterion: 47.098955600493255
# Number of iterations: 44
# Criterion: 70.09782075212661
# Number of iterations: 45
# Criterion: 107.37074767260451
# Number of iterations: 41
# Criterion: 164.93498560383713
# Number of iterations: 40
# Criterion: 245.55358729862022
# Number of iterations: 43
# Criterion: 341.4076510805928
# Number of iterations: 38
# Criterion: 428.37305628560705
# Number of iterations: 33
# Criterion: 473.61960544169864
# Number of iterations: 31
# Criterion: 26.345877672225537
# Number of iterations: 39
# Criterion: 33.360958097809636
# Number of iterations: 42
# Criterion: 45.21841334216586
# Number of iterations: 44
# Criterion: 65.32264273098244
# Number of iterations: 45
# Criterion: 98.69872921523472
# Number of iterations: 41
# Criterion: 151.3287832181539
# Number of iterations: 40
# Criterion: 227.06194944355735
# Number of iterations: 44
# Criterion: 320.8595772742156
# Number of iterations: 38
# Criterion: 411.8801757562963
# Number of iterations: 32
# Criterion: 467.6317444400516
# Number of iterations: 39
# Criterion: 26.69458167871865
# Number of iterations: 31
# Criterion: 32.599551320695255
# Number of iterations: 32
# Criterion: 43.00419534995794
# Number of iterations: 33
# Criterion: 61.033707123555345
# Number of iterations: 33
# Criterion: 91.37371153878638
# Number of iterations: 47
# Criterion: 139.91485106087794
# Number of iterations: 42
# Criterion: 211.2573466409507
# Number of iterations: 41
# Criterion: 302.56663144872994
# Number of iterations: 39
# Criterion: 396.07474366306695
# Number of iterations: 37
# Criterion: 460.33370984880804
# Number of iterations: 41
# Mlmnet([-7.924291302073635 -4.278340378104617 … -0.6961706174677971 -8.095375939192282; 9.335652102696374 -0.0 … 0.0 0.0; … ; -8.640383579637758 -0.0 … -0.0 -0.0; -2.0251037280126893 -0.0 … -0.0 -0.0;;; -7.948047450767887 -4.27936123307744 … -0.6961706959214091 -8.095376098990863; 9.335751525357358 -0.0 … 0.0 0.0; … ; -8.640426696294458 -0.0 … -0.0 -0.0; -2.0250706175077946 -0.0 … -0.0 -0.0;;; -8.42610211224222 -4.289130793122506 … -0.6961706665360483 -8.093712770645718; 9.316173391488505 -0.0 … 0.0 0.0; … ; -8.640417183691067 -0.0 … -0.0 -0.0; -2.0250779177933493 -0.0 … -0.0 -0.0;;; -9.326633913816554 -4.294767281307395 … -0.7438087631605879 -8.093642317293847; 9.248902493378182 -0.0 … 0.0 0.0; … ; -8.561858300904698 -0.0 … -0.3714496413073767 -0.0; -2.025082215581464 -0.0 … -0.0 -0.0;;; -10.979144940978708 -4.138647841850664 … -0.7224095995265675 -7.980494615503578; 9.209709373336757 -0.0 … 0.0 0.0; … ; -8.387466427715625 -1.1356587568242758 … -2.0454188333799315 -0.0; -1.890195875659347 -1.819221477302855 … -0.504804489184494 -1.89502130388028;;; -11.05993418448696 -3.9594885818189463 … -0.7054571736730948 -7.710649998948067; 9.127321507693315 0.0 … 1.3651634292625052 0.0; … ; -8.252068770540744 -2.022915375350873 … -3.1407032283733756 -0.22249701040754283; -1.7881030550963148 -3.3185419303229273 … -1.098614623831271 -3.4996497976791834;;; -11.673932550844274 -3.9050135064453344 … -0.6496065389337665 -7.503446537720005; 9.055925583945921 0.0 … 2.5087218953539967 0.25236784394916145; … ; -8.215558443718548 -2.3246932730674645 … -3.836704284861393 -0.8401032781189438; -1.7898777080970911 -4.174441629331851 … -1.444004633745443 -4.341268565814322;;; -12.86288263594396 -3.8800511312278636 … -0.6285574747593821 -7.410335109313412; 8.956783604167862 0.21698689471780663 … 3.433021676040443 0.9634858795288165; … ; -8.183228023592287 -2.534639897003558 … -4.223847223804692 -1.305383834770338; -1.8283577698636966 -4.585561879543308 … -1.6965475843849798 -4.614736499651364;;; -13.696347842476964 -3.8706925080573797 … -0.6202752396928903 -7.36064498417236; 8.87152407131088 0.5736300651253937 … 3.990163274966715 1.393271345112133; … ; -8.15152218667224 -2.6764229245310562 … -4.452908946566929 -1.5773359519319847; -1.860647085893282 -4.778230240231247 … -1.8460276809212248 -4.761434614385055;;; -14.253454917751673 -3.8660016479493486 … -0.6282473482756281 -7.335635760108508; 8.810057792451573 0.7886612809288353 … 4.478438169527295 1.675970316270791; … ; -8.126814009300546 -2.7610618974576395 … -4.700013360210887 -1.7478063257559209; -1.8830481128001544 -4.883654509100086 … -1.8649420767828 -4.829955588926337;;;; -574.6206566368517 -157.03507054845392 … -25.552711988104527 -297.13811355549376; 342.6588733276594 -0.0 … 0.0 0.0; … ; -317.14107925282184 -0.0 … -0.0 -0.0; -74.33182114517986 -0.0 … -0.0 -0.0;;; -322.8743835347426 -89.14923559976872 … -14.50536246001776 -168.67468076672785; 194.5184159812767 -0.0 … 0.0 0.0; … ; -180.03103951218844 -0.0 … -0.0 -0.0; -42.194440995933036 -0.0 … -0.0 -0.0;;; -183.61012262241357 -51.44647003152879 … -8.36794387384379 -97.30317244703858; 112.20382638529469 -0.0 … 0.0 0.0; … ; -103.85742896843651 -0.0 … -0.0 -0.0; -24.341391217594747 -0.0 … -0.0 -0.0;;; -106.76424648832105 -30.47905841720323 … -5.013414925690562 -57.64508878478887; 66.58523735489945 -0.0 … 0.0 0.0; … ; -61.35527898182224 -0.3668787199798733 … -1.0757300885556227 -0.0; -14.43557250125765 -0.0 … -0.0 -0.4880576299068558;;; -65.12256164277069 -18.679792624988938 … -3.0762990464423026 -35.48293412394208; 41.23384740393918 -0.5961855241289404 … 0.0 0.0; … ; -37.598939897544724 -2.0491323684287295 … -2.8591857758782773 -0.0; -8.847243757912038 -1.1357680788838662 … -1.1681270101871453 -2.452103062716979;;; -41.47083933607868 -12.102560266973978 … -1.9749788009283402 -23.046785674283228; 27.10444556472627 -0.6679582585030552 … 0.20073174256824486 0.0; … ; -24.36566114858324 -2.8085927024645176 … -3.712533589759252 -0.9068692457406788; -5.696 ...

# %% [markdown]
# If `alphas` argument is omitted, a Lasso regression will be applied which is equivalent to `alphas = [1]`.
#
# The functions for the algorithms used to fit the Elastic Net penalized estimates have keyword arguments that can be passed into `mlmnet` when non-default behavior is desired. Irrelevant keyword arguments will be ignored.
#
# `"cd"` (coordinate descent)
# - `isRandom= true`: Bool; whether to use random or cyclic updates
#
# `"cd_active"` (active coordinate descent)
# - `isRandom = true`: Bool; whether to use random or cyclic updates
#
# `"ista"` (ISTA with fixed step size)
# - `stepsize = 0.01`: Float64; fixed step size for updates
# - `setStepsize = true`: Bool; whether the fixed step size should be calculated, overriding `stepsize`
#
# `"fista"` (FISTA with fixed step size)
# - `stepsize = 0.01`: Float64; fixed step size for updates
# - `setStepsize = true`: Bool; whether the fixed step size should be calculated, overriding `stepsize`
#
# `"fista_bt"` (FISTA with backtracking)
# - `stepsize = 0.01`: Float64; initial step size for updates
# - `gamma = 0.5`: Float64; multiplying factor for step size backtracking/line search
#
# `"admm"` (ADMM)
# - `rho = 1.0`: Float64; parameter that controls ADMM tuning
# - `setRho = true`: Float64; whether the ADMM tuning parameter should be calculated, overriding `rho`
# - `tau_incr = 2.0`: Float64; parameter that controls the factor at which the ADMM tuning parameter increases
# - `tau_decr = 2.0`: Float64; parameter that controls the factor at which the ADMM tuning parameter decreases
# - `mu = 10.0`: Float64; parameter that controls the factor at which the primal and dual residuals should be within each other
#
# The 4d array of coefficient estimates can be accessed using `coef(est)`. Predicted values and residuals can be obtained by calling `predict` and `resid`. By default, both of these functions use the same data used to fit the model. However, a new `Predictors` object can be passed into `predict` as the `newPredictors` argument and a new `RawData` object can be passed into `resid` as the `newData` argument. For convenience, `fitted(est)` will return the fitted values by calling `predict` with the default arguments.

# %%
preds = predict(est)
resids = resid(est)

estPerms = mlmnet_perms(dat, lambdas, alphas; method = "fista_bt")
# Out:
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.04730309446663
# Number of iterations: 1
# Criterion: 156.28402752501606
# Number of iterations: 675
# Criterion: 207.04214578963789
# Number of iterations: 369
# Criterion: 231.9668636721151
# Number of iterations: 524
# Criterion: 219.63465697913898
# Number of iterations: 429
# Criterion: 198.2961556548988
# Number of iterations: 864
# Criterion: 175.6608859554169
# Number of iterations: 369
# Criterion: 158.99716489719935
# Number of iterations: 172
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.04730309446663
# Number of iterations: 1
# Criterion: 138.20508044858119
# Number of iterations: 196
# Criterion: 152.88673764808834
# Number of iterations: 411
# Criterion: 170.75507495643203
# Number of iterations: 189
# Criterion: 185.353871805172
# Number of iterations: 646
# Criterion: 188.8874311470762
# Number of iterations: 694
# Criterion: 182.9239112003929
# Number of iterations: 675
# Criterion: 171.62816030176492
# Number of iterations: 513
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.04730309446663
# Number of iterations: 1
# Criterion: 137.44295222864957
# Number of iterations: 133
# Criterion: 145.83707050545027
# Number of iterations: 280
# Criterion: 157.08125624560412
# Number of iterations: 375
# Criterion: 168.63726502055567
# Number of iterations: 485
# Criterion: 176.96175132224354
# Number of iterations: 600
# Criterion: 178.7330036707671
# Number of iterations: 654
# Criterion: 173.86596541179722
# Number of iterations: 613
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.10810637672066
# Number of iterations: 27
# Criterion: 137.31032607668655
# Number of iterations: 121
# Criterion: 143.15292990878123
# Number of iterations: 221
# Criterion: 151.16682153301863
# Number of iterations: 317
# Criterion: 160.1275146434767
# Number of iterations: 405
# Criterion: 168.52000438784233
# Number of iterations: 516
# Criterion: 173.40165480101126
# Number of iterations: 588
# Criterion: 173.40778613551726
# Number of iterations: 642
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.2365611459497
# Number of iterations: 37
# Criterion: 137.25433279884084
# Number of iterations: 108
# Criterion: 141.6211187826532
# Number of iterations: 182
# Criterion: 147.472364679532
# Number of iterations: 251
# Criterion: 154.93084700724157
# Number of iterations: 355
# Criterion: 162.5630387056067
# Number of iterations: 452
# Criterion: 169.25485134321892
# Number of iterations: 567
# Criterion: 171.7350728474364
# Number of iterations: 630
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.04730367033596
# Number of iterations: 36
# Criterion: 135.39086786834793
# Number of iterations: 37
# Criterion: 137.2231256030798
# Number of iterations: 90
# Criterion: 140.4883446685682
# Number of iterations: 137
# Criterion: 145.18152561366952
# Number of iterations: 216
# Criterion: 151.1225146902303
# Number of iterations: 300
# Criterion: 158.5123272107016
# Number of iterations: 424
# Criterion: 164.9561065846128
# Number of iterations: 496
# Criterion: 169.74850297946006
# Number of iterations: 610
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.05924076066313
# Number of iterations: 36
# Criterion: 135.60967451123437
# Number of iterations: 36
# Criterion: 137.2005322814339
# Number of iterations: 51
# Criterion: 139.82989490036704
# Number of iterations: 132
# Criterion: 143.55902139531037
# Number of iterations: 196
# Criterion: 148.45041281072506
# Number of iterations: 266
# Criterion: 155.07669959431132
# Number of iterations: 381
# Criterion: 162.1058246980013
# Number of iterations: 487
# Criterion: 167.3170719597331
# Number of iterations: 565
# Criterion: 135.04907782289692
# Number of iterations: 197
# Criterion: 135.1441013242942
# Number of iterations: 36
# Criterion: 135.8344405461583
# Number of iterations: 48
# Criterion: 137.20857540572322
# Number of iterations: 79
# Criterion: 139.1650269214749
# Number of iterations: 105
# Criterion: 142.30700375176164
# Number of iterations: 185
# Criterion: 146.45160049548826
# Number of iterations: 247
# Criterion: 152.43612044519486
# Number of iterations: 351
# Criterion: 159.30942300341349
# Number of iterations: 452
# Criterion: 165.15646588325583
# Number of iterations: 531
# Criterion: 135.06670038322937
# Number of iterations: 197
# Criterion: 135.32788671349755
# Number of iterations: 36
# Criterion: 136.0074527671914
# Number of iterations: 45
# Criterion: 137.05742167551637
# Number of iterations: 68
# Criterion: 138.67722600185272
# Number of iterations: 109
# Criterion: 141.06403250923557
# Number of iterations: 155
# Criterion: 144.89808741030714
# Number of iterations: 236
# Criterion: 150.33646374895613
# Number of iterations: 330
# Criterion: 156.9956989966942
# Number of iterations: 427
# Criterion: 163.2088263093093
# Number of iterations: 505
# Criterion: 135.21265432342943
# Number of iterations: 197
# Criterion: 135.53173392664954
# Number of iterations: 36
# Criterion: 136.04126906154826
# Number of iterations: 41
# Criterion: 136.7989862959238
# Number of iterations: 58
# Criterion: 138.0350235229168
# Number of iterations: 93
# Criterion: 140.1701744690848
# Number of iterations: 152
# Criterion: 143.333360316581
# Number of iterations: 202
# Criterion: 148.28350219924394
# Number of iterations: 287
# Criterion: 155.10940373380618
# Number of iterations: 413
# Criterion: 161.47149520255763
# Number of iterations: 487
# Criterion: 135.2673934986185
# Number of iterations: 197
# Criterion: 135.43892256124886
# Number of iterations: 36
# Criterion: 135.76196485584694
# Number of iterations: 34
# Criterion: 136.32598271047476
# Number of iterations: 48
# Criterion: 137.3490407737446
# Number of iterations: 78
# Criterion: 139.21443636424442
# Number of iterations: 134
# Criterion: 142.27390279648222
# Number of iterations: 201
# Criterion: 146.89516929199786
# Number of iterations: 281
# Criterion: 152.98615997874384
# Number of iterations: 364
# Criterion: 160.01276734487786
# Number of iterations: 479
# Mlmnet([12.443408216415428 -4.230847274888264 … -0.7032917026718124 -8.128196227303997; 7.158177878137566 0.0 … -0.0 -0.0; … ; -16.37081848292532 -0.0 … -0.0 -0.0; 3.736983164260677 0.0 … -0.0 0.0;;; 12.412315525537553 -4.274627234898147 … -0.6988790877560112 -8.099946454427602; 7.116824610009 0.0 … -0.0 -0.0; … ; -16.302280355398683 -0.0 … -0.0 -0.0; 3.758312692957218 0.0 … -0.0 0.0;;; 12.412260380992796 -4.2746568332583585 … -0.6988553452978227 -8.099910559914402; 7.116795849517562 0.0 … -0.0 -0.0; … ; -16.302239651115617 -0.0 … -0.0 -0.0; 3.7582974536786278 0.0 … -0.0 0.0;;; 12.662645035762274 -4.27924085617419 … -0.6954752134246621 -8.093906923673142; 7.113492704407816 0.0 … -0.0 -0.0; … ; -16.241877558129005 -0.0 … -0.0 -0.0; 3.757931544273566 0.0 … -0.0 0.0;;; 13.971785347656352 -4.223741916180748 … -0.6800536668750533 -8.095771816162907; 7.028441046585453 0.0 … -0.0 -0.0; … ; -16.068983130741934 -1.4401634293742056 … -0.2956434967493522 -0.0; 3.7400108540375605 0.0 … -0.0 0.0;;; 17.64576475558464 -4.187933853200771 … -0.60104065753362 -8.065122741144398; 7.0443843732047755 0.29455693603878647 … -0.0 -1.1576195406977416; … ; -15.747675625709034 -2.465340460563321 … -1.7326734496243898 -0.0; 3.704905706930153 0.0 … -0.0 0.0;;; 20.093811802492432 -4.177269804815831 … -0.5837443799576159 -8.053400972364326; 6.968262840407288 0.9272722205963232 … -0.0 -1.5829559422663897; … ; -15.576923082093185 -2.983100966899945 … -2.156912648649057 -0.08821653818439117; 3.6940051326684316 0.038598023598943834 … -0.0 0.0;;; 21.336086899858596 -4.179701541147262 … -0.5794736286734672 -8.051488255252492; 6.8675822988174895 1.4996364293322584 … 0.0 -1.9012808476495802; … ; -15.436887141126803 -3.3723570503222517 … -2.498188108036823 -0.4416287009031439; 3.6241364626882278 0.5537939766438456 … -0.0240104230227843 0.13263729269224606;;; 22.24815985711965 -4.173785893605713 … -0.5718966205315266 -8.069454290655564; 6.801487737161122 1.770895722559623 … 0.0 -2.0056724012675136; … ; -15.357905918096014 -3.6307560285045883 … -2.6744193446050737 -0.6532716460494671; 3.5812631556657144 0.8950755122559144 … -0.18775089789498134 0.4033219747479027;;; 22.770407203439042 -4.173245384592898 … -0.5694693600719669 -8.079454452519666; 6.754314900866082 1.9466173417526424 … 0.09549733886577806 -2.0384654610486397; … ; -15.305449279164444 -3.7738973829596913 … -2.8362962999245815 -0.7952595216101976; 3.5521370292995202 1.082924726262849 … -0.26814491992181755 0.5490856611561504;;;; 172.96771131292797 -155.29186263328836 … -25.81409145413478 -298.3427786388816; 262.7385730404886 0.0 … -0.0 -0.0; … ; -600.8855271458782 -0.0 … -0.0 -0.0; 137.16474230864466 0.0 … -0.0 0.0;;; 100.97573150267226 -89.06582972511039 … -14.561795077787767 -168.76990952633327; 148.28565254149936 0.0 … -0.0 -0.0; … ; -339.6731566231056 -0.0 … -0.0 -0.0; 78.30793656856129 0.0 … -0.0 0.0;;; 61.61355045535841 -51.38120661169447 … -8.400213698806697 -97.36060559929722; 85.54360553864154 0.0 … -0.0 -0.0; … ; -195.9522779069137 -0.0 … -0.0 -0.0; 45.1745872260983 0.0 … -0.0 0.0;;; 40.00820084651244 -30.454308711793942 … -4.970753243555821 -57.67883814197593; 50.67545473836371 0.0 … -0.0 -0.0; … ; -116.03766196953177 -0.05045753169867731 … -0.0 -0.0; 26.763439623099362 0.0 … -0.0 0.0;;; 29.19803907885793 -18.77526858336051 … -3.0483600711906695 -35.635419336992385; 31.265161536675095 0.0 … -0.0 -0.09779815439603369; … ; -71.51673064131745 -1.2715637553773071 … -0.3574226475480456 -0.0; 16.532561938353105 0.0 … -0.0 0.0;;; 24.57343551940326 -12.279654033048557 … -1.9505313868471597 -23.376367944892245; 20.528985690151398 0.0 … -0.0 -0.7015643480536241; … ; -46.680831657178594 -1.859197989812524 … -1.1365901687119926 -0.0; 10.817175503944235 0.0 … -0.0 0.0;;; 22.975723255009516 -8.657712989128184 … -1.3527635922029007 -16.583238835573066; 14.539588918145663 0.0 … -0.0 -1.0681490035670347; … ; -32.83813992228364 -2.3554556151732755 … -1.651056421002154 -0.14813324510521292; 7.655338109354506 0.0 …  ...

# %% [markdown]
# All four of these functions take optional `lambda` and `alpha` arguments, in which case only the 2d array corresponding to that values of lambda and alpha will be returned, e.g. `coef(est, lambdas[1], alphas[1])`. If a lambda or alpha value that was not used in the fitting of the `Mlmnet` object is passed in, an error will be raised. One can also extract coefficients as a flattened 3d array by calling `coef_3d(est)`, for convenience when writing the results to flat files.
#
# `mlmnet_perms` permutes the response matrix `Y` in a `RawData` object and then calls `mlmnet`. By default, the function used to permute `Y` is `shuffle_rows`, which shuffles the rows for `Y`. Alternative functions for permuting `Y`, such as `shuffle_cols`, can be passed into the argument `permFun`. Non-default behavior for `mlmnet` can be specified by passing its keyword arguments into `mlmnet_perms`.

# %% [markdown]
# Cross-validation for `mlmnet` is implemented by `mlmnet_cv`. The user can either manually specify the row/column folds of `Y` as a 1d array of 1d arrays of row/column indices, or specify the number of folds that should be used. If the number of folds is specified, disjoint folds of approximately equal size will be generated from a call to `make_folds`. Passing in `1` for the number of row (or column) folds indicates that all of the rows (or columns) of `Y` should be used in each fold. The advantage of manually passing in the row and/or column folds is that it allows the user to stratify or otherwise control the nature of the folds. For example, `make_folds_conds` will generate folds for a set of categorical conditions and ensure that each condition is represented in each fold. Cross validation is computed in parallel when possible. Non-default behavior for `mlmnet` can be specified by passing its keyword arguments into `mlmnet_cv`.
#
# In the call below, `mlmnet_cv` generates 10 disjoint row folds but uses all columns of `Y` in each fold (indicated by the `1`). The function returns an `Mlmnet_cv` object, which contains an array of the Mlmnet objects for each fold (`MLMNets`); the lambda penalty values used (`lambdas`); the row and column folds (`rowFolds` and `colFolds`); an array of the mean-squared error for each fold (`mse`); and an array of the proportion of zero interaction effects for each fold (`propZero`). The keyword argument `dig` in `mlmnet_cv` adjusts the level of precision when calculating the percent of zero coefficients. It defaults to `12`.

# %%
estCVObjs = mlmnet_cv(dat, lambdas, alphas, 10, 1, method = "fista_bt")
println(mlmnet_cv_summary(estCVObjs))
# Out:
# Performing 10-fold cross validation.
# Criterion: 19.016385002245304
# Number of iterations: 270
# Criterion: 219.58082566151023
# Number of iterations: 1791
# Criterion: 382.91946404489516
# Number of iterations: 1482
# Criterion: 548.945422439869
# Number of iterations: 1166
# Criterion: 607.3122393835783
# Number of iterations: 1577
# Criterion: 500.21442510375385
# Number of iterations: 222
# Criterion: 347.0867552532113
# Number of iterations: 1203
# Criterion: 218.74585251142926
# Number of iterations: 289
# Criterion: 131.16705101770128
# Number of iterations: 704
# Criterion: 76.28900490597903
# Number of iterations: 224
# Criterion: 19.016385002245304
# Number of iterations: 270
# Criterion: 29.853024124757088
# Number of iterations: 311
# Criterion: 59.73782669105457
# Number of iterations: 473
# Criterion: 115.60135465466414
# Number of iterations: 586
# Criterion: 192.55855879327368
# Number of iterations: 740
# Criterion: 256.22869759491687
# Number of iterations: 779
# Criterion: 296.2040333444169
# Number of iterations: 867
# Criterion: 293.70987037447316
# Number of iterations: 789
# Criterion: 257.0303751866069
# Number of iterations: 498
# Criterion: 200.63342794906504
# Number of iterations: 863
# Criterion: 19.079667590889756
# Number of iterations: 270
# Criterion: 26.33328296120118
# Number of iterations: 225
# Criterion: 41.10143745042194
# Number of iterations: 307
# Criterion: 72.14154870681367
# Number of iterations: 426
# Criterion: 118.7717933298749
# Number of iterations: 585
# Criterion: 168.34898385036968
# Number of iterations: 653
# Criterion: 219.81449474710848
# Number of iterations: 775
# Criterion: 256.072375850278
# Number of iterations: 863
# Criterion: 262.8904253485367
# Number of iterations: 888
# Criterion: 235.37237810944433
# Number of iterations: 696
# Criterion: 19.239715581746236
# Number of iterations: 270
# Criterion: 24.8049380773639
# Number of iterations: 150
# Criterion: 35.10274982623453
# Number of iterations: 241
# Criterion: 56.945501952018596
# Number of iterations: 383
# Criterion: 88.58772719416238
# Number of iterations: 501
# Criterion: 128.23864397034657
# Number of iterations: 610
# Criterion: 173.75030751972855
# Number of iterations: 703
# Criterion: 220.87333653318288
# Number of iterations: 843
# Criterion: 246.09249192861705
# Number of iterations: 858
# Criterion: 242.48382672577995
# Number of iterations: 770
# Criterion: 19.610017326320758
# Number of iterations: 270
# Criterion: 24.06150280915023
# Number of iterations: 151
# Criterion: 32.47273399972032
# Number of iterations: 226
# Criterion: 48.5109220487832
# Number of iterations: 336
# Criterion: 71.6485692127043
# Number of iterations: 434
# Criterion: 102.18412295526949
# Number of iterations: 517
# Criterion: 144.31819214326492
# Number of iterations: 659
# Criterion: 190.6803304819669
# Number of iterations: 775
# Criterion: 228.70029809975483
# Number of iterations: 859
# Criterion: 242.37831311754215
# Number of iterations: 880
# Criterion: 20.156725167171285
# Number of iterations: 270
# Criterion: 23.520721178538164
# Number of iterations: 123
# Criterion: 30.580961945405654
# Number of iterations: 181
# Criterion: 42.68667918320189
# Number of iterations: 273
# Criterion: 61.29687706568325
# Number of iterations: 400
# Criterion: 85.97478029489542
# Number of iterations: 468
# Criterion: 122.15912386886137
# Number of iterations: 589
# Criterion: 169.6186444481063
# Number of iterations: 761
# Criterion: 210.97879122972674
# Number of iterations: 831
# Criterion: 234.59224796594992
# Number of iterations: 843
# Criterion: 20.537565591143476
# Number of iterations: 270
# Criterion: 23.365809188283187
# Number of iterations: 103
# Criterion: 29.23644202994253
# Number of iterations: 142
# Criterion: 38.6035396175395
# Number of iterations: 215
# Criterion: 53.18851723586165
# Number of iterations: 340
# Criterion: 75.07090051875127
# Number of iterations: 450
# Criterion: 106.59695475558766
# Number of iterations: 550
# Criterion: 150.76558574369113
# Number of iterations: 711
# Criterion: 197.10124385492503
# Number of iterations: 839
# Criterion: 226.75762314316097
# Number of iterations: 851
# Criterion: 20.66839444476762
# Number of iterations: 270
# Criterion: 23.41909818234379
# Number of iterations: 89
# Criterion: 28.409242990590407
# Number of iterations: 169
# Criterion: 35.97106562264115
# Number of iterations: 235
# Criterion: 48.05855384029526
# Number of iterations: 335
# Criterion: 66.98943506564177
# Number of iterations: 439
# Criterion: 95.16829276099017
# Number of iterations: 533
# Criterion: 136.13986749148506
# Number of iterations: 680
# Criterion: 182.2381596251107
# Number of iterations: 800
# Criterion: 219.99658820774164
# Number of iterations: 884
# Criterion: 20.93591850535852
# Number of iterations: 270
# Criterion: 23.366536361563973
# Number of iterations: 77
# Criterion: 27.28681368969574
# Number of iterations: 149
# Criterion: 33.24410241322797
# Number of iterations: 204
# Criterion: 43.33259801173722
# Number of iterations: 299
# Criterion: 59.574454194392175
# Number of iterations: 388
# Criterion: 86.52238568293298
# Number of iterations: 530
# Criterion: 124.51029189892066
# Number of iterations: 661
# Criterion: 169.7786404012074
# Number of iterations: 775
# Criterion: 210.27017641227002
# Number of iterations: 854
# Criterion: 21.192610383419684
# Number of iterations: 270
# Criterion: 23.01528672179871
# Number of iterations: 65
# Criterion: 25.96191433171911
# Number of iterations: 130
# Criterion: 30.827794641971337
# Number of iterations: 177
# Criterion: 39.45361328141057
# Number of iterations: 265
# Criterion: 54.82560403375998
# Number of iterations: 397
# Criterion: 77.58918067373313
# Number of iterations: 469
# Criterion: 112.62604856743894
# Number of iterations: 592
# Criterion: 159.65063544920503
# Number of iterations: 766
# Criterion: 201.3707470514719
# Number of iterations: 835
# Criterion: 20.652021291079283
# Number of iterations: 270
# Criterion: 21.961229592665678
# Number of iterations: 52
# Criterion: 24.364773454272694
# Number of iterations: 114
# Criterion: 28.57137034542395
# Number of iterations: 153
# Criterion: 36.169531812213854
# Number of iterations: 233
# Criterion: 49.927593086385656
# Number of iterations: 364
# Criterion: 72.20826722801434
# Number of iterations: 485
# Criterion: 105.16066684042063
# Number of iterations: 599
# Criterion: 147.22114063145114
# Number of iterations: 691
# Criterion: 193.90687272866288
# Number of iterations: 833
# Criterion: 19.421674212811972
# Number of iterations: 241
# Criterion: 235.2177324335485
# Number of iterations: 1700
# Criterion: 394.80259128881943
# Number of iterations: 1593
# Criterion: 585.8365190311678
# Number of iterations: 1435
# Criterion: 615.7180936549448
# Number of iterations: 335
# Criterion: 503.30145200725184
# Number of iterations: 1390
# Criterion: 347.4400288885011
# Number of iterations: 311
# Criterion: 219.27294182834146
# Number of iterations: 198
# Criterion: 131.33485794181854
# Number of iterations: 230
# Criterion: 76.3961795199691
# Number of iterations: 195
# Criterion: 19.421674212811972
# Number of iterations: 241
# Criterion: 30.845268614842297
# Number of iterations: 313
# Criterion: 61.62007942161542
# Number of iterations: 472
# Criterion: 121.19612032581762
# Number of iterations: 587
# Criterion: 200.96857144718172
# Number of iterations: 736
# Criterion: 264.2344141306269
# Number of iterations: 767
# Criterion: 303.5607291034856
# Number of iterations: 847
# Criterion: 299.3358095276424
# Number of iterations: 762
# Criterion: 259.8123232564464
# Number of iterations: 117
# Criterion: 202.1912967163812
# Number of iterations: 864
# Criterion: 19.49045968174124
# Number of iterations: 241
# Criterion: 27.19332032168832
# Number of iterations: 227
# Criterion: 42.46533793940597
# Number of iterations: 307
# Criterion: 75.47476394721538
# Number of iterations: 427
# Criterion: 123.79247108202318
# Number of iterations: 584
# Criterion: 174.4896321601151
# Number of iterations: 647
# Criterion: 226.78221955905883
# Number of iterations: 768
# Criterion: 262.822712847178
# Number of iterations: 850
# Criterion: 267.91503993267634
# Number of iterations: 864
# Criterion: 238.153551628145
# Number of iterations: 624
# Criterion: 19.655260608867497
# Number of iterations: 241
# Criterion: 25.49628272029105
# Number of iterations: 151
# Criterion: 36.31539838142432
# Number of iterations: 242
# Criterion: 59.47502580163998
# Number of iterations: 385
# Criterion: 92.18165485761023
# Number of iterations: 500
# Criterion: 133.0683919918446
# Number of iterations: 608
# Criterion: 179.71318393472694
# Number of iterations: 699
# Criterion: 227.5679433539805
# Number of iterations: 836
# Criterion: 252.01305935116997
# Number of iterations: 842
# Criterion: 246.57272064514024
# Number of iterations: 733
# Criterion: 20.095013622093024
# Number of iterations: 241
# Criterion: 24.6768325757602
# Number of iterations: 152
# Criterion: 33.60439784393944
# Number of iterations: 227
# Criterion: 50.47139462415795
# Number of iterations: 337
# Criterion: 74.4352766017456
# Number of iterations: 434
# Criterion: 106.03409917038081
# Number of iterations: 516
# Criterion: 149.43952634765063
# Number of iterations: 656
# Criterion: 196.95855585353078
# Number of iterations: 771
# Criterion: 234.9232795892096
# Number of iterations: 847
# Criterion: 247.28294420416842
# Number of iterations: 856
# Criterion: 20.626122768703063
# Number of iterations: 241
# Criterion: 24.106380060714073
# Number of iterations: 123
# Criterion: 31.624527200596305
# Number of iterations: 182
# Criterion: 44.28324681231754
# Number of iterations: 273
# Criterion: 63.6174074007143
# Number of iterations: 400
# Criterion: 89.19206392478256
# Number of iterations: 467
# Criterion: 126.5849525916538
# Number of iterations: 586
# Criterion: 175.42952261471413
# Number of iterations: 758
# Criterion: 217.18629171574983
# Number of iterations: 821
# Criterion: 240.0040249098709
# Number of iterations: 823
# Criterion: 21.02177497761113
# Number of iterations: 241
# Criterion: 23.98929008683839
# Number of iterations: 104
# Criterion: 30.221078708442743
# Number of iterations: 143
# Criterion: 39.96366257501776
# Number of iterations: 215
# Criterion: 55.13132606457257
# Number of iterations: 340
# Criterion: 77.84818226186943
# Number of iterations: 450
# Criterion: 110.51182604888311
# Number of iterations: 548
# Criterion: 156.0481663461641
# Number of iterations: 708
# Criterion: 203.3086805967561
# Number of iterations: 833
# Criterion: 232.49097552178878
# Number of iterations: 836
# Criterion: 21.14437471018022
# Number of iterations: 241
# Criterion: 24.067878957138205
# Number of iterations: 90
# Criterion: 29.298547796830697
# Number of iterations: 170
# Criterion: 37.17113339539133
# Number of iterations: 235
# Criterion: 48.79988872034598
# Number of iterations: 279
# Criterion: 69.5594391179152
# Number of iterations: 443
# Criterion: 98.67676583697045
# Number of iterations: 532
# Criterion: 141.02584862332162
# Number of iterations: 677
# Criterion: 188.23261757113198
# Number of iterations: 795
# Criterion: 225.9367556146307
# Number of iterations: 873
# Criterion: 21.441704989665606
# Number of iterations: 241
# Criterion: 24.01036158125347
# Number of iterations: 78
# Criterion: 28.093451057885645
# Number of iterations: 149
# Criterion: 34.30163996122256
# Number of iterations: 205
# Criterion: 44.809077623437986
# Number of iterations: 300
# Criterion: 61.72744956217869
# Number of iterations: 389
# Criterion: 89.74651588897827
# Number of iterations: 530
# Criterion: 129.06362501748234
# Number of iterations: 659
# Criterion: 175.51285636237282
# Number of iterations: 771
# Criterion: 216.2437453602776
# Number of iterations: 843
# Criterion: 21.71288871688113
# Number of iterations: 241
# Criterion: 23.6123294210656
# Number of iterations: 65
# Criterion: 26.68598259703548
# Number of iterations: 131
# Criterion: 31.759859594480844
# Number of iterations: 178
# Criterion: 40.763487938640175
# Number of iterations: 266
# Criterion: 56.79747533155832
# Number of iterations: 398
# Criterion: 80.4799771559857
# Number of iterations: 469
# Criterion: 116.77935420915509
# Number of iterations: 590
# Criterion: 165.1605544399195
# Number of iterations: 763
# Criterion: 207.3498629980956
# Number of iterations: 826
# Criterion: 21.133080588793923
# Number of iterations: 241
# Criterion: 22.502573763340713
# Number of iterations: 53
# Criterion: 25.01639621962105
# Number of iterations: 115
# Criterion: 29.414442752804568
# Number of iterations: 154
# Criterion: 37.35310908885218
# Number of iterations: 234
# Criterion: 51.71111820065951
# Number of iterations: 365
# Criterion: 74.91242337973718
# Number of iterations: 485
# Criterion: 109.08734925405452
# Number of iterations: 598
# Criterion: 152.38580504831037
# Number of iterations: 687
# Criterion: 199.87316929253313
# Number of iterations: 826
# Criterion: 19.26551431578122
# Number of iterations: 201
# Criterion: 233.8492811968037
# Number of iterations: 1400
# Criterion: 402.9690229673166
# Number of iterations: 1592
# Criterion: 569.0540084039314
# Number of iterations: 1621
# Criterion: 610.1303929608024
# Number of iterations: 1163
# Criterion: 504.10921697422384
# Number of iterations: 1335
# Criterion: 347.6364999107473
# Number of iterations: 1245
# Criterion: 218.9026761080598
# Number of iterations: 322
# Criterion: 131.38498245625652
# Number of iterations: 87
# Criterion: 76.31688523992564
# Number of iterations: 188
# Criterion: 19.26551431578122
# Number of iterations: 201
# Criterion: 31.092569627119698
# Number of iterations: 316
# Criterion: 61.09359552718712
# Number of iterations: 471
# Criterion: 118.19176905586178
# Number of iterations: 585
# Criterion: 196.45635843943262
# Number of iterations: 737
# Criterion: 260.70547295725174
# Number of iterations: 774
# Criterion: 300.6018191633493
# Number of iterations: 858
# Criterion: 296.4468020454525
# Number of iterations: 764
# Criterion: 258.5525292409602
# Number of iterations: 408
# Criterion: 202.48569459503216
# Number of iterations: 766
# Criterion: 19.37932350566246
# Number of iterations: 201
# Criterion: 27.08039323401768
# Number of iterations: 228
# Criterion: 42.1679551669445
# Number of iterations: 307
# Criterion: 73.70731235259217
# Number of iterations: 425
# Criterion: 121.26975380801812
# Number of iterations: 585
# Criterion: 175.63473588446834
# Number of iterations: 718
# Criterion: 223.2198387473623
# Number of iterations: 768
# Criterion: 259.953667023647
# Number of iterations: 858
# Criterion: 265.4838421908211
# Number of iterations: 871
# Criterion: 237.0806792970509
# Number of iterations: 669
# Criterion: 19.5299408034892
# Number of iterations: 201
# Criterion: 25.339345389675653
# Number of iterations: 152
# Criterion: 36.01505618452549
# Number of iterations: 242
# Criterion: 58.17564243910233
# Number of iterations: 383
# Criterion: 90.40926752605577
# Number of iterations: 501
# Criterion: 130.81902300059687
# Number of iterations: 610
# Criterion: 177.0032133169052
# Number of iterations: 701
# Criterion: 224.65198690220763
# Number of iterations: 840
# Criterion: 249.35831781395802
# Number of iterations: 848
# Criterion: 244.81355842772467
# Number of iterations: 751
# Criterion: 19.961892397235385
# Number of iterations: 201
# Criterion: 24.48434710137367
# Number of iterations: 152
# Criterion: 33.138542680424194
# Number of iterations: 227
# Criterion: 49.473555805026876
# Number of iterations: 336
# Criterion: 73.0903029579087
# Number of iterations: 434
# Criterion: 104.24267454147494
# Number of iterations: 517
# Criterion: 147.12239660366595
# Number of iterations: 658
# Criterion: 194.18146703026517
# Number of iterations: 773
# Criterion: 232.20294665766258
# Number of iterations: 853
# Criterion: 245.11816864018306
# Number of iterations: 865
# Criterion: 20.510779927898948
# Number of iterations: 201
# Criterion: 23.91005778619776
# Number of iterations: 123
# Criterion: 31.144151084905623
# Number of iterations: 181
# Criterion: 43.49915382257367
# Number of iterations: 273
# Criterion: 62.52379361833829
# Number of iterations: 401
# Criterion: 87.71102368853235
# Number of iterations: 468
# Criterion: 124.5795989421324
# Number of iterations: 587
# Criterion: 172.90348000547203
# Number of iterations: 760
# Criterion: 214.46257127669452
# Number of iterations: 826
# Criterion: 237.67826762414185
# Number of iterations: 832
# Criterion: 20.865559118240927
# Number of iterations: 201
# Criterion: 23.79973724493778
# Number of iterations: 103
# Criterion: 29.762883869236873
# Number of iterations: 142
# Criterion: 39.32258347290833
# Number of iterations: 215
# Criterion: 54.23119804529166
# Number of iterations: 340
# Criterion: 76.58683211926366
# Number of iterations: 450
# Criterion: 108.75039770982431
# Number of iterations: 549
# Criterion: 153.7213708023802
# Number of iterations: 710
# Criterion: 200.57414003828245
# Number of iterations: 835
# Criterion: 230.03405750732992
# Number of iterations: 843
# Criterion: 20.982753438135244
# Number of iterations: 201
# Criterion: 23.795005133587825
# Number of iterations: 90
# Criterion: 28.887889141649275
# Number of iterations: 169
# Criterion: 36.62000380657644
# Number of iterations: 235
# Criterion: 48.04889405431162
# Number of iterations: 278
# Criterion: 68.4557048093733
# Number of iterations: 443
# Criterion: 97.10225181694665
# Number of iterations: 533
# Criterion: 138.85733039189518
# Number of iterations: 678
# Criterion: 185.60913664605843
# Number of iterations: 797
# Criterion: 223.387918384684
# Number of iterations: 878
# Criterion: 21.258503522311347
# Number of iterations: 201
# Criterion: 23.723853515071685
# Number of iterations: 77
# Criterion: 27.733899212161838
# Number of iterations: 149
# Criterion: 33.83055229804684
# Number of iterations: 204
# Criterion: 44.155808946133234
# Number of iterations: 300
# Criterion: 60.76839619220825
# Number of iterations: 388
# Criterion: 88.30882080693502
# Number of iterations: 530
# Criterion: 127.04969788589003
# Number of iterations: 660
# Criterion: 173.01387817341723
# Number of iterations: 773
# Criterion: 213.6669268264913
# Number of iterations: 848
# Criterion: 21.495671716449742
# Number of iterations: 201
# Criterion: 23.359947871014914
# Number of iterations: 65
# Criterion: 26.376385670699715
# Number of iterations: 131
# Criterion: 31.359426454450897
# Number of iterations: 177
# Criterion: 40.19137557355387
# Number of iterations: 266
# Criterion: 55.92488587259108
# Number of iterations: 397
# Criterion: 79.19827357191149
# Number of iterations: 469
# Criterion: 114.94825254082403
# Number of iterations: 591
# Criterion: 162.74772437211672
# Number of iterations: 765
# Criterion: 204.76949294617668
# Number of iterations: 830
# Criterion: 20.942416799754373
# Number of iterations: 201
# Criterion: 22.284155214016515
# Number of iterations: 52
# Criterion: 24.747567545438216
# Number of iterations: 115
# Criterion: 29.05837434056933
# Number of iterations: 153
# Criterion: 36.84251809262419
# Number of iterations: 234
# Criterion: 50.92971345390278
# Number of iterations: 365
# Criterion: 73.71900284739147
# Number of iterations: 485
# Criterion: 107.35521688955758
# Number of iterations: 598
# Criterion: 150.12450742380412
# Number of iterations: 689
# Criterion: 197.29608920798464
# Number of iterations: 829
# Criterion: 19.14985274637676
# Number of iterations: 206
# Criterion: 232.5906682058969
# Number of iterations: 1729
# Criterion: 399.8604814818788
# Number of iterations: 1513
# Criterion: 546.6582688277814
# Number of iterations: 1604
# Criterion: 605.4391174126732
# Number of iterations: 1690
# Criterion: 502.32566480643516
# Number of iterations: 59
# Criterion: 344.12528614730866
# Number of iterations: 139
# Criterion: 218.01860314448996
# Number of iterations: 1040
# Criterion: 130.88386659998287
# Number of iterations: 167
# Criterion: 76.26782077217531
# Number of iterations: 863
# Criterion: 19.14985274637676
# Number of iterations: 206
# Criterion: 30.86162136578244
# Number of iterations: 316
# Criterion: 61.33045701698197
# Number of iterations: 473
# Criterion: 118.51611599905546
# Number of iterations: 584
# Criterion: 197.3339089401573
# Number of iterations: 735
# Criterion: 264.73855414439174
# Number of iterations: 841
# Criterion: 297.93076988336173
# Number of iterations: 845
# Criterion: 293.79517836742207
# Number of iterations: 767
# Criterion: 255.74741944478515
# Number of iterations: 407
# Criterion: 200.58906538092407
# Number of iterations: 722
# Criterion: 19.249242666915457
# Number of iterations: 206
# Criterion: 26.912322941687847
# Number of iterations: 228
# Criterion: 42.239653550574275
# Number of iterations: 308
# Criterion: 73.97475329772999
# Number of iterations: 425
# Criterion: 121.74742430695362
# Number of iterations: 584
# Criterion: 175.55185478784057
# Number of iterations: 713
# Criterion: 222.64723755024607
# Number of iterations: 763
# Criterion: 257.82015753011467
# Number of iterations: 846
# Criterion: 263.009505200994
# Number of iterations: 870
# Criterion: 234.4026471688211
# Number of iterations: 664
# Criterion: 19.408919554834796
# Number of iterations: 206
# Criterion: 25.179753825707913
# Number of iterations: 152
# Criterion: 36.00810175346318
# Number of iterations: 243
# Criterion: 58.42199499189576
# Number of iterations: 383
# Criterion: 90.72285848062447
# Number of iterations: 500
# Criterion: 131.0157972738333
# Number of iterations: 607
# Criterion: 176.83816513825747
# Number of iterations: 698
# Criterion: 223.5281327151747
# Number of iterations: 834
# Criterion: 247.1601210672966
# Number of iterations: 840
# Criterion: 242.28605590463337
# Number of iterations: 750
# Criterion: 19.829784836660835
# Number of iterations: 206
# Criterion: 24.388692327528297
# Number of iterations: 152
# Criterion: 33.13584761681211
# Number of iterations: 227
# Criterion: 49.74794068967468
# Number of iterations: 337
# Criterion: 73.32587806138345
# Number of iterations: 434
# Criterion: 104.48689195294835
# Number of iterations: 515
# Criterion: 147.12685810200102
# Number of iterations: 655
# Criterion: 193.53272661819932
# Number of iterations: 769
# Criterion: 230.41308238713546
# Number of iterations: 843
# Criterion: 242.73955187826527
# Number of iterations: 862
# Criterion: 20.382778331403838
# Number of iterations: 206
# Criterion: 23.83666821428622
# Number of iterations: 124
# Criterion: 31.108918434069015
# Number of iterations: 181
# Criterion: 43.65503261510468
# Number of iterations: 273
# Criterion: 62.713055622497635
# Number of iterations: 400
# Criterion: 87.93350612017665
# Number of iterations: 467
# Criterion: 127.68273440530939
# Number of iterations: 648
# Criterion: 172.01432613037383
# Number of iterations: 750
# Criterion: 213.2663772370589
# Number of iterations: 821
# Criterion: 235.43780878961618
# Number of iterations: 825
# Criterion: 20.737690490066736
# Number of iterations: 206
# Criterion: 23.713453526712197
# Number of iterations: 104
# Criterion: 29.7513986405674
# Number of iterations: 142
# Criterion: 39.38921227282664
# Number of iterations: 215
# Criterion: 54.37197957090957
# Number of iterations: 340
# Criterion: 76.77370570741067
# Number of iterations: 449
# Criterion: 111.51346968478697
# Number of iterations: 609
# Criterion: 153.09621477349452
# Number of iterations: 700
# Criterion: 199.67439922561553
# Number of iterations: 832
# Criterion: 228.0027160594199
# Number of iterations: 835
# Criterion: 20.87603225471283
# Number of iterations: 206
# Criterion: 23.70513144012638
# Number of iterations: 90
# Criterion: 28.893997937559597
# Number of iterations: 170
# Criterion: 36.65508848336121
# Number of iterations: 235
# Criterion: 48.14759243557148
# Number of iterations: 278
# Criterion: 68.61249341109647
# Number of iterations: 442
# Criterion: 97.24817317761847
# Number of iterations: 531
# Criterion: 138.75721378428165
# Number of iterations: 675
# Criterion: 184.85754202712505
# Number of iterations: 793
# Criterion: 221.61285862558023
# Number of iterations: 871
# Criterion: 21.158452402105944
# Number of iterations: 206
# Criterion: 23.66982475081957
# Number of iterations: 77
# Criterion: 27.69788685575663
# Number of iterations: 149
# Criterion: 33.83965676198479
# Number of iterations: 205
# Criterion: 44.21743382827208
# Number of iterations: 300
# Criterion: 60.894004221859625
# Number of iterations: 388
# Criterion: 88.46358619030417
# Number of iterations: 529
# Criterion: 127.03484823941594
# Number of iterations: 658
# Criterion: 172.42504374125184
# Number of iterations: 769
# Criterion: 212.15165795429525
# Number of iterations: 841
# Criterion: 21.410871400330134
# Number of iterations: 206
# Criterion: 23.28354305397823
# Number of iterations: 65
# Criterion: 26.32456692048509
# Number of iterations: 131
# Criterion: 31.33871079376214
# Number of iterations: 178
# Criterion: 40.225509929368826
# Number of iterations: 266
# Criterion: 56.035470346424034
# Number of iterations: 397
# Criterion: 79.33949077209422
# Number of iterations: 468
# Criterion: 117.79625821029953
# Number of iterations: 653
# Criterion: 161.85814505528472
# Number of iterations: 755
# Criterion: 203.52198842736
# Number of iterations: 825
# Criterion: 20.841225832528885
# Number of iterations: 206
# Criterion: 22.19431682979543
# Number of iterations: 52
# Criterion: 24.677742662824407
# Number of iterations: 115
# Criterion: 29.021286178816908
# Number of iterations: 154
# Criterion: 36.85713622389342
# Number of iterations: 234
# Criterion: 51.015829911683426
# Number of iterations: 365
# Criterion: 73.85751629551157
# Number of iterations: 484
# Criterion: 107.41625102272023
# Number of iterations: 596
# Criterion: 149.79112644818335
# Number of iterations: 685
# Criterion: 196.1451938332484
# Number of iterations: 824
# Criterion: 19.139674896501287
# Number of iterations: 199
# Criterion: 242.23583445691796
# Number of iterations: 1802
# Criterion: 404.8331452598635
# Number of iterations: 1996
# Criterion: 567.3274581305976
# Number of iterations: 1637
# Criterion: 609.5157721528843
# Number of iterations: 1648
# Criterion: 499.28573994025425
# Number of iterations: 1203
# Criterion: 345.57000042294777
# Number of iterations: 1055
# Criterion: 217.731221467849
# Number of iterations: 293
# Criterion: 130.50000704757707
# Number of iterations: 98
# Criterion: 75.77704925806196
# Number of iterations: 316
# Criterion: 19.139674896501287
# Number of iterations: 199
# Criterion: 30.238655406043492
# Number of iterations: 312
# Criterion: 60.7066083969273
# Number of iterations: 473
# Criterion: 116.44387710887443
# Number of iterations: 587
# Criterion: 193.8534851658314
# Number of iterations: 741
# Criterion: 258.15745026628315
# Number of iterations: 783
# Criterion: 299.8940698370541
# Number of iterations: 871
# Criterion: 299.4513086693911
# Number of iterations: 877
# Criterion: 260.0385207788895
# Number of iterations: 665
# Criterion: 201.54815520323262
# Number of iterations: 800
# Criterion: 19.24386511588235
# Number of iterations: 199
# Criterion: 26.611446237251787
# Number of iterations: 226
# Criterion: 41.882509582491615
# Number of iterations: 308
# Criterion: 72.48466212041275
# Number of iterations: 425
# Criterion: 119.29283404410137
# Number of iterations: 586
# Criterion: 169.46951697758195
# Number of iterations: 655
# Criterion: 222.2255678998938
# Number of iterations: 779
# Criterion: 259.07780393802375
# Number of iterations: 862
# Criterion: 265.2040591704923
# Number of iterations: 874
# Criterion: 236.46848337782708
# Number of iterations: 642
# Criterion: 19.411236706254943
# Number of iterations: 199
# Criterion: 25.032124391217287
# Number of iterations: 151
# Criterion: 35.67990029474054
# Number of iterations: 36
# Criterion: 57.23139999405291
# Number of iterations: 383
# Criterion: 88.8526724568987
# Number of iterations: 501
# Criterion: 129.03386169414924
# Number of iterations: 612
# Criterion: 175.4239613913305
# Number of iterations: 707
# Criterion: 223.54274979242112
# Number of iterations: 846
# Criterion: 248.7237192094994
# Number of iterations: 851
# Criterion: 247.33483433153143
# Number of iterations: 871
# Criterion: 19.77332217482934
# Number of iterations: 199
# Criterion: 24.237305708645323
# Number of iterations: 151
# Criterion: 32.782276741144756
# Number of iterations: 226
# Criterion: 48.7372287435319
# Number of iterations: 336
# Criterion: 71.88117815859344
# Number of iterations: 435
# Criterion: 102.79925550968795
# Number of iterations: 519
# Criterion: 145.57041716987024
# Number of iterations: 661
# Criterion: 192.82056718369944
# Number of iterations: 777
# Criterion: 231.47408043121516
# Number of iterations: 858
# Criterion: 244.7419445379822
# Number of iterations: 868
# Criterion: 20.307500838214743
# Number of iterations: 199
# Criterion: 23.734363660074766
# Number of iterations: 123
# Criterion: 30.785485091976245
# Number of iterations: 181
# Criterion: 42.852516277336356
# Number of iterations: 273
# Criterion: 61.53131656639512
# Number of iterations: 400
# Criterion: 86.48087229562347
# Number of iterations: 469
# Criterion: 123.14693299105967
# Number of iterations: 591
# Criterion: 171.44415071833976
# Number of iterations: 763
# Criterion: 213.5965789036688
# Number of iterations: 833
# Criterion: 237.1256466682256
# Number of iterations: 834
# Criterion: 20.689663762195707
# Number of iterations: 199
# Criterion: 23.626255529182387
# Number of iterations: 104
# Criterion: 29.40625593709464
# Number of iterations: 142
# Criterion: 38.74306639848365
# Number of iterations: 215
# Criterion: 53.418549959544066
# Number of iterations: 340
# Criterion: 75.50230745074222
# Number of iterations: 451
# Criterion: 107.42325352982434
# Number of iterations: 552
# Criterion: 152.30920125802913
# Number of iterations: 713
# Criterion: 199.49685335187468
# Number of iterations: 841
# Criterion: 229.3961259480835
# Number of iterations: 846
# Criterion: 20.819871928311724
# Number of iterations: 199
# Criterion: 23.579111279548496
# Number of iterations: 89
# Criterion: 28.554110549129152
# Number of iterations: 168
# Criterion: 36.12136034470571
# Number of iterations: 235
# Criterion: 47.375423804429985
# Number of iterations: 279
# Criterion: 67.48274582840818
# Number of iterations: 443
# Criterion: 95.86383879290024
# Number of iterations: 535
# Criterion: 137.4767506716984
# Number of iterations: 681
# Criterion: 184.39882994855097
# Number of iterations: 801
# Criterion: 222.70383131446485
# Number of iterations: 883
# Criterion: 21.102908219936616
# Number of iterations: 199
# Criterion: 23.50632658828274
# Number of iterations: 77
# Criterion: 27.41395456132443
# Number of iterations: 148
# Criterion: 33.406244521265094
# Number of iterations: 204
# Criterion: 43.55509502875688
# Number of iterations: 300
# Criterion: 59.91760308138162
# Number of iterations: 389
# Criterion: 87.15031498940019
# Number of iterations: 532
# Criterion: 125.68915980257587
# Number of iterations: 663
# Criterion: 171.7389709580118
# Number of iterations: 777
# Criterion: 212.8861697599104
# Number of iterations: 853
# Criterion: 21.32233187589558
# Number of iterations: 199
# Criterion: 23.14173115405326
# Number of iterations: 64
# Criterion: 26.103815749722326
# Number of iterations: 130
# Criterion: 30.991516269584665
# Number of iterations: 177
# Criterion: 39.664584663671974
# Number of iterations: 266
# Criterion: 55.14768697768733
# Number of iterations: 397
# Criterion: 78.14327771299315
# Number of iterations: 471
# Criterion: 113.65289256975015
# Number of iterations: 594
# Criterion: 161.4437467100292
# Number of iterations: 768
# Criterion: 203.88139531354582
# Number of iterations: 835
# Criterion: 20.781386633461235
# Number of iterations: 199
# Criterion: 22.09541824823737
# Number of iterations: 52
# Criterion: 24.508830504574817
# Number of iterations: 114
# Criterion: 28.734921574822277
# Number of iterations: 153
# Criterion: 36.37516286442171
# Number of iterations: 234
# Criterion: 50.22898080753257
# Number of iterations: 365
# Criterion: 72.7169556559518
# Number of iterations: 486
# Criterion: 106.08778924558625
# Number of iterations: 600
# Criterion: 148.83501414875994
# Number of iterations: 694
# Criterion: 196.32324505800887
# Number of iterations: 834
# Criterion: 19.126591918251403
# Number of iterations: 267
# Criterion: 232.94355925094828
# Number of iterations: 1799
# Criterion: 395.7670066547082
# Number of iterations: 1561
# Criterion: 575.3859348317584
# Number of iterations: 1619
# Criterion: 608.8777188326819
# Number of iterations: 1469
# Criterion: 496.3362965552796
# Number of iterations: 1017
# Criterion: 343.62739327527026
# Number of iterations: 1113
# Criterion: 217.27046004790583
# Number of iterations: 221
# Criterion: 130.40897595532462
# Number of iterations: 302
# Criterion: 75.98340585427606
# Number of iterations: 329
# Criterion: 19.126591918251403
# Number of iterations: 267
# Criterion: 29.851549926825985
# Number of iterations: 309
# Criterion: 60.64815861934021
# Number of iterations: 474
# Criterion: 118.57999310908819
# Number of iterations: 588
# Criterion: 196.56168437858366
# Number of iterations: 736
# Criterion: 264.82754506384526
# Number of iterations: 847
# Criterion: 297.9582571945259
# Number of iterations: 848
# Criterion: 297.3183197937542
# Number of iterations: 873
# Criterion: 256.2259176251307
# Number of iterations: 457
# Criterion: 199.68129979398105
# Number of iterations: 894
# Criterion: 19.20310299367108
# Number of iterations: 267
# Criterion: 26.43651694847255
# Number of iterations: 225
# Criterion: 41.906608201684556
# Number of iterations: 308
# Criterion: 73.72549045836028
# Number of iterations: 426
# Criterion: 121.1179504850413
# Number of iterations: 584
# Criterion: 174.94748258878232
# Number of iterations: 716
# Criterion: 222.12499362221774
# Number of iterations: 765
# Criterion: 257.9751451275466
# Number of iterations: 851
# Criterion: 263.2475196461222
# Number of iterations: 869
# Criterion: 234.92338823238543
# Number of iterations: 669
# Criterion: 19.37595685562796
# Number of iterations: 267
# Criterion: 24.915563624340702
# Number of iterations: 150
# Criterion: 35.80486347835582
# Number of iterations: 243
# Criterion: 58.124627346587644
# Number of iterations: 384
# Criterion: 90.18018582579577
# Number of iterations: 500
# Criterion: 130.30645971829205
# Number of iterations: 609
# Criterion: 176.21845853012593
# Number of iterations: 701
# Criterion: 223.2809230883131
# Number of iterations: 837
# Criterion: 247.34038167593826
# Number of iterations: 843
# Criterion: 242.66879098724883
# Number of iterations: 747
# Criterion: 19.707711421224833
# Number of iterations: 267
# Criterion: 24.18028981651586
# Number of iterations: 151
# Criterion: 33.02977900289456
# Number of iterations: 228
# Criterion: 49.42985175719769
# Number of iterations: 337
# Criterion: 72.85627231029409
# Number of iterations: 434
# Criterion: 103.82926569967577
# Number of iterations: 517
# Criterion: 146.4782555166552
# Number of iterations: 657
# Criterion: 193.15964586148473
# Number of iterations: 772
# Criterion: 230.4479679602561
# Number of iterations: 847
# Criterion: 243.08938567634254
# Number of iterations: 863
# Criterion: 20.25679836629953
# Number of iterations: 267
# Criterion: 23.713601240759548
# Number of iterations: 123
# Criterion: 31.03424233927681
# Number of iterations: 182
# Criterion: 43.391568512015496
# Number of iterations: 273
# Criterion: 62.28110827673712
# Number of iterations: 400
# Criterion: 87.34083312384365
# Number of iterations: 467
# Criterion: 124.03469542701022
# Number of iterations: 587
# Criterion: 171.97999989146174
# Number of iterations: 759
# Criterion: 213.04756556236774
# Number of iterations: 823
# Criterion: 235.75648469101515
# Number of iterations: 828
# Criterion: 20.64790337159643
# Number of iterations: 267
# Criterion: 23.641324939622457
# Number of iterations: 104
# Criterion: 29.63579558163026
# Number of iterations: 142
# Criterion: 39.17529577794154
# Number of iterations: 215
# Criterion: 53.999490856017225
# Number of iterations: 340
# Criterion: 76.2531663269607
# Number of iterations: 450
# Criterion: 108.26968572499197
# Number of iterations: 549
# Criterion: 152.92568543965547
# Number of iterations: 709
# Criterion: 199.36199061847873
# Number of iterations: 834
# Criterion: 228.23357819824494
# Number of iterations: 839
# Criterion: 20.807186099795096
# Number of iterations: 267
# Criterion: 23.66555296812841
# Number of iterations: 90
# Criterion: 28.770476491499256
# Number of iterations: 169
# Criterion: 36.449200742135055
# Number of iterations: 235
# Criterion: 48.75696002375821
# Number of iterations: 336
# Criterion: 68.03516708720217
# Number of iterations: 439
# Criterion: 96.67787056875989
# Number of iterations: 533
# Criterion: 138.15479652934079
# Number of iterations: 677
# Criterion: 184.51728985380726
# Number of iterations: 796
# Criterion: 221.7419193980055
# Number of iterations: 875
# Criterion: 21.112787495240237
# Number of iterations: 267
# Criterion: 23.5979610612142
# Number of iterations: 77
# Criterion: 27.587557537341254
# Number of iterations: 149
# Criterion: 33.65354872676365
# Number of iterations: 205
# Criterion: 43.93397845163776
# Number of iterations: 300
# Criterion: 60.485234633687774
# Number of iterations: 388
# Criterion: 87.9022089120134
# Number of iterations: 530
# Criterion: 126.41656136955575
# Number of iterations: 660
# Criterion: 172.02051106695905
# Number of iterations: 772
# Criterion: 212.17064195394718
# Number of iterations: 845
# Criterion: 21.3623766919027
# Number of iterations: 267
# Criterion: 23.215776925953154
# Number of iterations: 65
# Criterion: 26.21801048601693
# Number of iterations: 131
# Criterion: 31.181486202080446
# Number of iterations: 178
# Criterion: 39.98251667265427
# Number of iterations: 266
# Criterion: 55.65582890634411
# Number of iterations: 397
# Criterion: 78.82216423138526
# Number of iterations: 469
# Criterion: 114.37533324596733
# Number of iterations: 591
# Criterion: 161.83787167048573
# Number of iterations: 764
# Criterion: 203.39763219091066
# Number of iterations: 828
# Criterion: 20.79754749655821
# Number of iterations: 267
# Criterion: 22.134899375263608
# Number of iterations: 53
# Criterion: 24.58976855672512
# Number of iterations: 115
# Criterion: 28.885167729813453
# Number of iterations: 154
# Criterion: 36.64028304224364
# Number of iterations: 234
# Criterion: 50.671715236036675
# Number of iterations: 365
# Criterion: 73.36118655976534
# Number of iterations: 485
# Criterion: 106.82188876893281
# Number of iterations: 598
# Criterion: 149.29666173982272
# Number of iterations: 688
# Criterion: 196.0133214938574
# Number of iterations: 828
# Criterion: 19.1354011224806
# Number of iterations: 296
# Criterion: 213.13939286295965
# Number of iterations: 1821
# Criterion: 391.4354722531263
# Number of iterations: 1545
# Criterion: 574.361473694093
# Number of iterations: 459
# Criterion: 620.5193757050882
# Number of iterations: 1839
# Criterion: 499.0792736067649
# Number of iterations: 1257
# Criterion: 344.72246285590666
# Number of iterations: 1237
# Criterion: 217.26795825576778
# Number of iterations: 210
# Criterion: 130.23044129865022
# Number of iterations: 446
# Criterion: 75.8985892634813
# Number of iterations: 325
# Criterion: 19.1354011224806
# Number of iterations: 296
# Criterion: 29.310595730272453
# Number of iterations: 306
# Criterion: 60.146728612937665
# Number of iterations: 474
# Criterion: 117.89084899457835
# Number of iterations: 586
# Criterion: 197.07082573961264
# Number of iterations: 740
# Criterion: 260.26531776164416
# Number of iterations: 771
# Criterion: 299.319888523855
# Number of iterations: 851
# Criterion: 294.5142599473314
# Number of iterations: 750
# Criterion: 256.52115360398346
# Number of iterations: 370
# Criterion: 199.56982968188186
# Number of iterations: 916
# Criterion: 19.172908232807583
# Number of iterations: 296
# Criterion: 26.16932243466639
# Number of iterations: 223
# Criterion: 41.70704302949278
# Number of iterations: 309
# Criterion: 73.47517283390087
# Number of iterations: 426
# Criterion: 121.12661620048246
# Number of iterations: 586
# Criterion: 171.1686673909881
# Number of iterations: 651
# Criterion: 223.15733227169704
# Number of iterations: 772
# Criterion: 258.4537703019674
# Number of iterations: 851
# Criterion: 263.8275033639206
# Number of iterations: 868
# Criterion: 235.1381110828997
# Number of iterations: 653
# Criterion: 19.342611699170703
# Number of iterations: 296
# Criterion: 24.747718978946043
# Number of iterations: 149
# Criterion: 35.74731685128198
# Number of iterations: 243
# Criterion: 58.00568914021924
# Number of iterations: 384
# Criterion: 90.08778951717962
# Number of iterations: 501
# Criterion: 130.3883468834473
# Number of iterations: 610
# Criterion: 176.48196643079353
# Number of iterations: 702
# Criterion: 223.6538025202159
# Number of iterations: 837
# Criterion: 247.900620512772
# Number of iterations: 845
# Criterion: 243.00505457264467
# Number of iterations: 741
# Criterion: 19.64980656580248
# Number of iterations: 296
# Criterion: 24.075093377889193
# Number of iterations: 151
# Criterion: 32.94763433754993
# Number of iterations: 228
# Criterion: 49.33227836616123
# Number of iterations: 337
# Criterion: 72.79209867399601
# Number of iterations: 434
# Criterion: 103.86702577226
# Number of iterations: 517
# Criterion: 146.58827379681406
# Number of iterations: 657
# Criterion: 193.42011232610918
# Number of iterations: 772
# Criterion: 230.89802645908324
# Number of iterations: 848
# Criterion: 243.54139033744678
# Number of iterations: 862
# Criterion: 20.205740080433888
# Number of iterations: 266
# Criterion: 23.662961035762766
# Number of iterations: 123
# Criterion: 30.96081422238468
# Number of iterations: 182
# Criterion: 43.32639827592676
# Number of iterations: 273
# Criterion: 62.243814395339456
# Number of iterations: 400
# Criterion: 87.35916871961007
# Number of iterations: 468
# Criterion: 124.08396949685215
# Number of iterations: 587
# Criterion: 172.1396943200401
# Number of iterations: 760
# Criterion: 213.35969094088148
# Number of iterations: 824
# Criterion: 236.14865791220558
# Number of iterations: 828
# Criterion: 20.607577133535216
# Number of iterations: 266
# Criterion: 23.622591825827524
# Number of iterations: 104
# Criterion: 29.60316183673999
# Number of iterations: 142
# Criterion: 39.120694901184535
# Number of iterations: 215
# Criterion: 53.98354183510364
# Number of iterations: 340
# Criterion: 76.24457959360457
# Number of iterations: 450
# Criterion: 108.27201166666937
# Number of iterations: 549
# Criterion: 153.0139365061527
# Number of iterations: 709
# Criterion: 199.59858353486823
# Number of iterations: 835
# Criterion: 228.5991064481934
# Number of iterations: 839
# Criterion: 20.782313202404588
# Number of iterations: 266
# Criterion: 23.632005604818612
# Number of iterations: 90
# Criterion: 28.741947962548437
# Number of iterations: 169
# Criterion: 36.42873850520561
# Number of iterations: 235
# Criterion: 47.81352514260428
# Number of iterations: 278
# Criterion: 68.11540383003121
# Number of iterations: 443
# Criterion: 96.6363599553853
# Number of iterations: 533
# Criterion: 138.1905648996284
# Number of iterations: 678
# Criterion: 184.69498314822306
# Number of iterations: 797
# Criterion: 222.06039924843896
# Number of iterations: 876
# Criterion: 21.11141501203607
# Number of iterations: 266
# Criterion: 23.589812900330486
# Number of iterations: 77
# Criterion: 27.572444644768886
# Number of iterations: 149
# Criterion: 33.64822104337727
# Number of iterations: 205
# Criterion: 43.9160732297823
# Number of iterations: 300
# Criterion: 60.4439767983437
# Number of iterations: 389
# Criterion: 87.85105312085737
# Number of iterations: 530
# Criterion: 126.4082751976922
# Number of iterations: 660
# Criterion: 172.12727978724536
# Number of iterations: 773
# Criterion: 212.4447942467184
# Number of iterations: 846
# Criterion: 21.362118621468184
# Number of iterations: 266
# Criterion: 23.21486226471032
# Number of iterations: 65
# Criterion: 26.218981681461237
# Number of iterations: 131
# Criterion: 31.172663666876105
# Number of iterations: 177
# Criterion: 39.955026209351104
# Number of iterations: 266
# Criterion: 55.60378848371195
# Number of iterations: 397
# Criterion: 78.75851306887792
# Number of iterations: 469
# Criterion: 114.33780846716044
# Number of iterations: 592
# Criterion: 161.89951403406383
# Number of iterations: 765
# Criterion: 203.61609778836296
# Number of iterations: 829
# Criterion: 20.801158035233136
# Number of iterations: 266
# Criterion: 22.134793335255345
# Number of iterations: 53
# Criterion: 24.583104143261995
# Number of iterations: 115
# Criterion: 28.867773020445263
# Number of iterations: 154
# Criterion: 36.60590336120112
# Number of iterations: 234
# Criterion: 50.61358198210624
# Number of iterations: 365
# Criterion: 73.28374826005319
# Number of iterations: 485
# Criterion: 106.75885176382488
# Number of iterations: 598
# Criterion: 149.32083881596247
# Number of iterations: 689
# Criterion: 196.19559490273838
# Number of iterations: 829
# Criterion: 19.32247550873179
# Number of iterations: 262
# Criterion: 247.45363787592825
# Number of iterations: 1743
# Criterion: 405.55715155724573
# Number of iterations: 1540
# Criterion: 552.3143199220679
# Number of iterations: 1459
# Criterion: 606.1562423162725
# Number of iterations: 1683
# Criterion: 499.7860139795747
# Number of iterations: 1279
# Criterion: 345.49786412452795
# Number of iterations: 263
# Criterion: 218.91434527832428
# Number of iterations: 268
# Criterion: 131.4440549628176
# Number of iterations: 1025
# Criterion: 76.41452002457794
# Number of iterations: 185
# Criterion: 19.32247550873179
# Number of iterations: 262
# Criterion: 31.55224944995247
# Number of iterations: 318
# Criterion: 62.37002379911121
# Number of iterations: 472
# Criterion: 121.153098734363
# Number of iterations: 584
# Criterion: 199.36147789743814
# Number of iterations: 733
# Criterion: 267.77746137329274
# Number of iterations: 842
# Criterion: 300.71924570863564
# Number of iterations: 840
# Criterion: 295.9725200797688
# Number of iterations: 748
# Criterion: 256.95335586385914
# Number of iterations: 67
# Criterion: 200.66910677182793
# Number of iterations: 828
# Criterion: 19.444101718661532
# Number of iterations: 262
# Criterion: 27.400222121673394
# Number of iterations: 229
# Criterion: 42.87150845274826
# Number of iterations: 308
# Criterion: 75.34270022157028
# Number of iterations: 426
# Criterion: 123.02920828285377
# Number of iterations: 583
# Criterion: 177.69688116937212
# Number of iterations: 713
# Criterion: 225.15885116152532
# Number of iterations: 761
# Criterion: 260.7271839242845
# Number of iterations: 842
# Criterion: 265.2099069876957
# Number of iterations: 860
# Criterion: 235.72937139007124
# Number of iterations: 642
# Criterion: 19.64228839566368
# Number of iterations: 262
# Criterion: 25.583638921526173
# Number of iterations: 153
# Criterion: 36.52519954407503
# Number of iterations: 243
# Criterion: 59.2112829329738
# Number of iterations: 384
# Criterion: 91.74502382140149
# Number of iterations: 499
# Criterion: 132.6135751618678
# Number of iterations: 607
# Criterion: 179.0475029056846
# Number of iterations: 697
# Criterion: 226.2934153019537
# Number of iterations: 833
# Criterion: 249.62377132538987
# Number of iterations: 830
# Criterion: 244.0334213791477
# Number of iterations: 728
# Criterion: 20.06803063880659
# Number of iterations: 262
# Criterion: 24.733569456994328
# Number of iterations: 153
# Criterion: 33.63580971187159
# Number of iterations: 228
# Criterion: 50.31478498591483
# Number of iterations: 337
# Criterion: 74.1969039524024
# Number of iterations: 434
# Criterion: 105.73625946890087
# Number of iterations: 515
# Criterion: 149.03960731043674
# Number of iterations: 655
# Criterion: 196.04098239029926
# Number of iterations: 768
# Criterion: 233.20187070968063
# Number of iterations: 842
# Criterion: 244.83380339014911
# Number of iterations: 850
# Criterion: 20.61194046547787
# Number of iterations: 262
# Criterion: 24.103657362940687
# Number of iterations: 124
# Criterion: 31.589145168370187
# Number of iterations: 182
# Criterion: 44.10542838928235
# Number of iterations: 273
# Criterion: 63.46214755226799
# Number of iterations: 400
# Criterion: 88.99117324084668
# Number of iterations: 467
# Criterion: 129.37857436300078
# Number of iterations: 649
# Criterion: 174.2944529275541
# Number of iterations: 750
# Criterion: 215.89722347987544
# Number of iterations: 819
# Criterion: 237.75185087268642
# Number of iterations: 814
# Criterion: 20.974190487357994
# Number of iterations: 262
# Criterion: 23.97867232354087
# Number of iterations: 104
# Criterion: 30.096979508984976
# Number of iterations: 143
# Criterion: 39.80969975986906
# Number of iterations: 215
# Criterion: 55.01258682866348
# Number of iterations: 340
# Criterion: 77.72231672203438
# Number of iterations: 449
# Criterion: 112.99896934915176
# Number of iterations: 609
# Criterion: 155.1631491700696
# Number of iterations: 700
# Criterion: 202.25360989877547
# Number of iterations: 830
# Criterion: 230.52387080271
# Number of iterations: 828
# Criterion: 21.091571408574435
# Number of iterations: 262
# Criterion: 23.99244587435295
# Number of iterations: 90
# Criterion: 29.1862096421384
# Number of iterations: 170
# Criterion: 37.06278448389742
# Number of iterations: 235
# Criterion: 49.6541833210926
# Number of iterations: 336
# Criterion: 69.36372846710888
# Number of iterations: 439
# Criterion: 98.55681167438183
# Number of iterations: 532
# Criterion: 140.6505974495821
# Number of iterations: 675
# Criterion: 187.30791794744647
# Number of iterations: 792
# Criterion: 224.2242249110402
# Number of iterations: 868
# Criterion: 21.370538733777376
# Number of iterations: 262
# Criterion: 23.907642831317293
# Number of iterations: 78
# Criterion: 27.981087506477405
# Number of iterations: 149
# Criterion: 34.20559470676827
# Number of iterations: 205
# Criterion: 44.73277376597554
# Number of iterations: 300
# Criterion: 61.66457627747499
# Number of iterations: 388
# Criterion: 89.6447477741358
# Number of iterations: 530
# Criterion: 128.78072075123654
# Number of iterations: 658
# Criterion: 174.7482852306981
# Number of iterations: 768
# Criterion: 214.7337722492179
# Number of iterations: 838
# Criterion: 21.61339422393626
# Number of iterations: 262
# Criterion: 23.511652075690275
# Number of iterations: 65
# Criterion: 26.5912783519684
# Number of iterations: 131
# Criterion: 31.679587221652525
# Number of iterations: 178
# Criterion: 40.700324613125204
# ...
# Number of iterations: 398
# Criterion: 78.89454550043706
# Number of iterations: 470
# Criterion: 114.67696063662069
# Number of iterations: 593
# Criterion: 162.68137258983276
# Number of iterations: 767
# Criterion: 204.9518154452397
# Number of iterations: 831
# Criterion: 20.863646152275503
# Number of iterations: 219
# Criterion: 22.19628982919489
# Number of iterations: 52
# Criterion: 24.643452321405736
# Number of iterations: 115
# Criterion: 28.92744133513878
# Number of iterations: 154
# Criterion: 36.668495230010464
# Number of iterations: 234
# Criterion: 50.693615585283275
# Number of iterations: 365
# Criterion: 73.42652793815525
# Number of iterations: 485
# Criterion: 107.0785060615987
# Number of iterations: 600
# Criterion: 150.0187493279765
# Number of iterations: 692
# Criterion: 197.46160812425438
# Number of iterations: 831
# Criterion: 18.93840808367956
# Number of iterations: 239
# Criterion: 175.71307036229072
# Number of iterations: 1792
# Criterion: 365.49352057118006
# Number of iterations: 1530
# Criterion: 578.8610503873465
# Number of iterations: 1863
# Criterion: 620.9769692009634
# Number of iterations: 1667
# Criterion: 499.60148947766373
# Number of iterations: 1214
# Criterion: 346.10338388868604
# Number of iterations: 1340
# Criterion: 217.92800953446437
# Number of iterations: 198
# Criterion: 130.59950373821954
# Number of iterations: 660
# Criterion: 75.95571767680244
# Number of iterations: 180
# Criterion: 18.93840808367956
# Number of iterations: 239
# Criterion: 28.075209486853637
# Number of iterations: 300
# Criterion: 57.75061720921846
# Number of iterations: 473
# Criterion: 114.84666598674404
# Number of iterations: 592
# Criterion: 192.85203072924628
# Number of iterations: 742
# Criterion: 255.93795742808896
# Number of iterations: 776
# Criterion: 297.2822176447794
# Number of iterations: 871
# Criterion: 297.23584988363757
# Number of iterations: 890
# Criterion: 256.2804821575385
# Number of iterations: 407
# Criterion: 200.22331749883017
# Number of iterations: 859
# Criterion: 18.990652283136388
# Number of iterations: 239
# Criterion: 25.370077158539953
# Number of iterations: 218
# Criterion: 40.658654319936076
# Number of iterations: 308
# Criterion: 71.6506696421371
# Number of iterations: 427
# Criterion: 118.47638968386644
# Number of iterations: 586
# Criterion: 167.99298576489116
# Number of iterations: 652
# Criterion: 219.71669169940418
# Number of iterations: 778
# Criterion: 256.1863415368168
# Number of iterations: 866
# Criterion: 262.359184615843
# Number of iterations: 879
# Criterion: 234.90567372599017
# Number of iterations: 685
# Criterion: 19.154834546150425
# Number of iterations: 239
# Criterion: 24.0921221817612
# Number of iterations: 146
# Criterion: 34.95463308026924
# Number of iterations: 243
# Criterion: 56.67254719438509
# Number of iterations: 383
# Criterion: 88.24793812615518
# Number of iterations: 501
# Criterion: 127.85516765398535
# Number of iterations: 610
# Criterion: 173.307026210425
# Number of iterations: 704
# Criterion: 220.74377966175396
# Number of iterations: 846
# Criterion: 245.7117240282373
# Number of iterations: 857
# Criterion: 241.94926465460597
# Number of iterations: 765
# Criterion: 19.321830359006867
# Number of iterations: 239
# Criterion: 23.5480909117043
# Number of iterations: 149
# Criterion: 32.26129460800223
# Number of iterations: 227
# Criterion: 48.302379239688946
# Number of iterations: 336
# Criterion: 71.35334809213802
# Number of iterations: 434
# Criterion: 101.81510633613472
# Number of iterations: 517
# Criterion: 143.78208135938297
# Number of iterations: 659
# Criterion: 190.30217539846464
# Number of iterations: 778
# Criterion: 228.25831564889575
# Number of iterations: 859
# Criterion: 241.86444942762031
# Number of iterations: 877
# Criterion: 19.899296527104216
# Number of iterations: 239
# Criterion: 23.224824746524103
# Number of iterations: 122
# Criterion: 30.347415579469608
# Number of iterations: 181
# Criterion: 42.50451838528214
# Number of iterations: 273
# Criterion: 61.057514217024654
# Number of iterations: 400
# Criterion: 85.60819738189198
# Number of iterations: 468
# Criterion: 121.62204817564921
# Number of iterations: 589
# Criterion: 169.0604837662725
# Number of iterations: 763
# Criterion: 210.4845183672686
# Number of iterations: 833
# Criterion: 234.08501000340556
# Number of iterations: 844
# Criterion: 20.2903560850062
# Number of iterations: 239
# Criterion: 23.25958450051106
# Number of iterations: 103
# Criterion: 29.090279980500164
# Number of iterations: 142
# Criterion: 38.43581313306075
# Number of iterations: 215
# Criterion: 52.967340961608926
# Number of iterations: 340
# Criterion: 74.70136055692258
# Number of iterations: 450
# Criterion: 106.07185156722619
# Number of iterations: 551
# Criterion: 150.13028761962812
# Number of iterations: 712
# Criterion: 196.54415015511282
# Number of iterations: 841
# Criterion: 226.18525199049418
# Number of iterations: 852
# Criterion: 20.485742561603903
# Number of iterations: 239
# Criterion: 23.280367718811974
# Number of iterations: 90
# Criterion: 28.287113776239433
# Number of iterations: 169
# Criterion: 35.81839099994022
# Number of iterations: 235
# Criterion: 46.92550863181241
# Number of iterations: 278
# Criterion: 66.73417480900603
# Number of iterations: 442
# Criterion: 94.6375013714619
# Number of iterations: 534
# Criterion: 135.49455915481548
# Number of iterations: 680
# Criterion: 181.6143105287102
# Number of iterations: 802
# Criterion: 219.38087752543763
# Number of iterations: 885
# Criterion: 20.842920458916318
# Number of iterations: 239
# Criterion: 23.261832550314715
# Number of iterations: 77
# Criterion: 27.170194550183204
# Number of iterations: 149
# Criterion: 33.09682370425868
# Number of iterations: 204
# Criterion: 43.10332278364602
# Number of iterations: 299
# Criterion: 59.22387638511982
# Number of iterations: 388
# Criterion: 86.01257811683953
# Number of iterations: 531
# Criterion: 123.8690092683121
# Number of iterations: 662
# Criterion: 169.09081938688792
# Number of iterations: 777
# Criterion: 209.62004648759475
# Number of iterations: 855
# Criterion: 21.102975583837274
# Number of iterations: 239
# Criterion: 22.918190116320787
# Number of iterations: 65
# Criterion: 25.84684954118513
# Number of iterations: 130
# Criterion: 30.669565437245602
# Number of iterations: 177
# Criterion: 39.22263093086914
# Number of iterations: 265
# Criterion: 54.47888806752418
# Number of iterations: 397
# Criterion: 77.10373109126192
# Number of iterations: 470
# Criterion: 111.99579280877094
# Number of iterations: 593
# Criterion: 158.91564021806812
# Number of iterations: 768
# Criterion: 200.69253189100183
# Number of iterations: 837
# Criterion: 20.558831469015214
# Number of iterations: 239
# Criterion: 21.855946839049317
# Number of iterations: 52
# Criterion: 24.237671863416878
# Number of iterations: 114
# Criterion: 28.407100792252066
# Number of iterations: 153
# Criterion: 35.941386462280875
# Number of iterations: 233
# Criterion: 49.59334569256322
# Number of iterations: 364
# Criterion: 71.72869446736608
# Number of iterations: 485
# Criterion: 104.52734006718086
# Number of iterations: 600
# Criterion: 146.49600294297286
# Number of iterations: 693
# Criterion: 193.1903205905761
# Number of iterations: 835
# 110×6 DataFrame
#  Row │ 𝜆_𝛼_Index  Lambda    Alpha    AvgMSE          StdMSE          AvgPropZero
#      │ Tuple…     Float64   Float64  Float64         Float64         Float64
# ─────┼───────────────────────────────────────────────────────────────────────────
#    1 │ (1, 1)     357.047       1.0      38.9581          2.59602         1.0
#    2 │ (2, 1)     198.359       1.0      34.6111          2.25909         0.966
#    3 │ (3, 1)     110.2         1.0      43.0145          3.09019         0.911
#    4 │ (4, 1)      61.222       1.0      82.7463         14.3265          0.743
#    5 │ (5, 1)      34.0122      1.0     113.876          37.2402          0.4735
#    6 │ (6, 1)      18.8957      1.0     162.363          63.7379          0.2825
#    7 │ (7, 1)      10.4976      1.0     211.134          91.9453          0.1675
#    8 │ (8, 1)       5.832       1.0     242.464         106.831           0.1
#    9 │ (9, 1)       3.24        1.0     262.839         114.532           0.0705
#   10 │ (10, 1)      1.8         1.0     273.824         117.645           0.06
#   11 │ (1, 2)     357.047       0.9       4.2269e5        1.76232e5       1.0
#   12 │ (2, 2)     198.359       0.9       1.30839e5   54532.8             0.9445
#   13 │ (3, 2)     110.2         0.9   41430.8         17292.3             0.875
#   14 │ (4, 2)      61.222       0.9   13591.2          5648.4             0.643
#   15 │ (5, 2)      34.0122      0.9    4898.49         2030.11            0.3765
#   16 │ (6, 2)      18.8957      0.9    2005.98          828.155           0.215
#   17 │ (7, 2)      10.4976      0.9     968.485         400.661           0.103
#   18 │ (8, 2)       5.832       0.9     563.693         237.343           0.056
#   19 │ (9, 2)       3.24        0.9     394.025         166.577           0.0335
#   20 │ (10, 2)      1.8         0.9     323.123         138.364           0.0185
#   21 │ (1, 3)     357.047       0.8       1.6905e6        7.04497e5       0.995
#   22 │ (2, 3)     198.359       0.8       5.23152e5       2.17999e5       0.938
#   23 │ (3, 3)     110.2         0.8       1.63513e5   68178.0             0.8285
#   24 │ (4, 3)      61.222       0.8   52074.4         21681.2             0.59
#   25 │ (5, 3)      34.0122      0.8   17404.2          7243.04            0.3285
#   26 │ (6, 3)      18.8957      0.8    6231.37         2587.7             0.1925
#   27 │ (7, 3)      10.4976      0.8    2482.96         1034.77            0.1035
#   28 │ (8, 3)       5.832       0.8    1150.58          478.225           0.045
#   29 │ (9, 3)       3.24        0.8     641.445         269.145           0.019
#   30 │ (10, 3)      1.8         0.8     429.393         181.522           0.007
#   31 │ (1, 4)     357.047       0.7       3.80321e6       1.58464e6       0.9915
#   32 │ (2, 4)     198.359       0.7       1.17695e6       4.90411e5       0.9355
#   33 │ (3, 4)     110.2         0.7       3.66413e5       1.52711e5       0.7845
#   34 │ (4, 4)      61.222       0.7       1.15713e5   48197.7             0.5185
#   35 │ (5, 4)      34.0122      0.7   37689.1         15699.7             0.288
#   36 │ (6, 4)      18.8957      0.7   12858.9          5359.41            0.1715
#   37 │ (7, 4)      10.4976      0.7    4727.17         1971.08            0.1005
#   38 │ (8, 4)       5.832       0.7    1968.23          817.779           0.039
#   39 │ (9, 4)       3.24        0.7     954.554         398.29            0.013
#   40 │ (10, 4)      1.8         0.7     561.38          236.686           0.006
#   41 │ (1, 5)     357.047       0.6       6.762e6         2.81696e6       0.9665
#   42 │ (2, 5)     198.359       0.6       2.09258e6       8.71847e5       0.928
#   43 │ (3, 5)     110.2         0.6       6.5037e5        2.70967e5       0.7205
#   44 │ (4, 5)      61.222       0.6       2.045e5     85185.6             0.4485
#   45 │ (5, 5)      34.0122      0.6   65744.4         27392.1             0.2515
#   46 │ (6, 5)      18.8957      0.6   21850.0          9107.04            0.1495
#   47 │ (7, 5)      10.4976      0.6    7715.31         3215.91            0.082
#   48 │ (8, 5)       5.832       0.6    3000.88         1249.11            0.0385
#   49 │ (9, 5)       3.24        0.6    1341.95          558.564           0.014
#   50 │ (10, 5)      1.8         0.6     718.38          300.919           0.003
#   51 │ (1, 6)     357.047       0.5       1.05717e7       4.40133e6       0.9445
#   52 │ (2, 6)     198.359       0.5       3.27088e6       1.36208e6       0.874
#   53 │ (3, 6)     110.2         0.5       1.01555e6       4.2283e5        0.6385
#   54 │ (4, 6)      61.222       0.5       3.18461e5       1.32599e5       0.366
#   55 │ (5, 6)      34.0122      0.5  101622.0         42321.2             0.21
#   56 │ (6, 6)      18.8957      0.5   33264.8         13857.3             0.126
#   57 │ (7, 6)      10.4976      0.5   11434.0          4758.39            0.0715
#   58 │ (8, 6)       5.832       0.5    4272.26         1779.74            0.029
#   59 │ (9, 6)       3.24        0.5    1796.88          746.882           0.0125
#   60 │ (10, 6)      1.8         0.5     892.032         372.489           0.0035
#   61 │ (1, 7)     357.047       0.4       1.52288e7       6.3402e6        0.9355
#   62 │ (2, 7)     198.359       0.4       4.71061e6       1.96143e6       0.7925
#   63 │ (3, 7)     110.2         0.4       1.46218e6       6.08789e5       0.532
#   64 │ (4, 7)      61.222       0.4       4.57609e5       1.90551e5       0.292
#   65 │ (5, 7)      34.0122      0.4       1.45194e5   60471.6             0.1725
#   66 │ (6, 7)      18.8957      0.4   47103.6         19619.1             0.1015
#   67 │ (7, 7)      10.4976      0.4   15897.9          6614.79            0.056
#   68 │ (8, 7)       5.832       0.4    5759.87         2399.04            0.027
#   69 │ (9, 7)       3.24        0.4    2327.38          967.236           0.008
#   70 │ (10, 7)      1.8         0.4    1090.82          454.687           0.0025
#   71 │ (1, 8)     357.047       0.3       2.07348e7       8.63256e6       0.9005
#   72 │ (2, 8)     198.359       0.3       6.41339e6       2.67011e6       0.672
#   73 │ (3, 8)     110.2         0.3       1.99125e6       8.29041e5       0.395
#   74 │ (4, 8)      61.222       0.3       6.22399e5       2.59167e5       0.225
#   75 │ (5, 8)      34.0122      0.3       1.96567e5   81835.1             0.1355
#   76 │ (6, 8)      18.8957      0.3   63371.2         26391.4             0.073
#   77 │ (7, 8)      10.4976      0.3   21108.7          8788.25            0.045
#   78 │ (8, 8)       5.832       0.3    7480.91         3114.35            0.0195
#   79 │ (9, 8)       3.24        0.3    2920.95         1214.77            0.007
#   80 │ (10, 8)      1.8         0.3    1315.36          547.497           0.0005
#   81 │ (1, 9)     357.047       0.2       2.70917e7       1.12786e7       0.748
#   82 │ (2, 9)     198.359       0.2       8.38214e6       3.48967e6       0.4795
#   83 │ (3, 9)     110.2         0.2       2.60232e6       1.08349e6       0.266
#   84 │ (4, 9)      61.222       0.2       8.12135e5       3.38169e5       0.158
#   85 │ (5, 9)      34.0122      0.2       2.5587e5   106552.0             0.091
#   86 │ (6, 9)      18.8957      0.2   81952.4         34126.2             0.053
#   87 │ (7, 9)      10.4976      0.2   27083.5         11276.0             0.0305
#   88 │ (8, 9)       5.832       0.2    9434.62         3926.33            0.0125
#   89 │ (9, 9)       3.24        0.2    3585.63         1491.36            0.005
#   90 │ (10, 9)      1.8         0.2    1554.51          646.655           0.0
#   91 │ (1, 10)    357.047       0.1       3.43126e7       1.42842e7       0.4345
#   92 │ (2, 10)    198.359       0.1       1.062e7         4.4214e6        0.242
#   93 │ (3, 10)    110.2         0.1       3.29552e6       1.3721e6        0.1445
#   94 │ (4, 10)     61.222       0.1       1.02714e6       4.27689e5       0.083
#   95 │ (5, 10)     34.0122      0.1       3.22828e5       1.34425e5       0.049
#   96 │ (6, 10)     18.8957      0.1       1.03062e5   42913.8             0.028
#   97 │ (7, 10)     10.4976      0.1   33736.0         14046.1             0.0145
#   98 │ (8, 10)      5.832       0.1   11593.3          4820.78            0.005
#   99 │ (9, 10)      3.24        0.1    4325.66         1799.32            0.002
#  100 │ (10, 10)     1.8         0.1    1816.54          755.438           0.0
#  101 │ (1, 11)    357.047       0.0       4.24168e7       1.76578e7       0.0
#  102 │ (2, 11)    198.359       0.0       1.31255e7       5.46433e6       0.0
#  103 │ (3, 11)    110.2         0.0       4.07079e6       1.69481e6       0.0
#  104 │ (4, 11)     61.222       0.0       1.26748e6       5.27728e5       0.0
#  105 │ (5, 11)     34.0122      0.0       3.9758e5        1.65545e5       0.0
#  106 │ (6, 11)     18.8957      0.0       1.2647e5    52659.4             0.0
#  107 │ (7, 11)     10.4976      0.0   41211.9         17157.7             0.0
#  108 │ (8, 11)      5.832       0.0   14009.0          5830.25            0.0
#  109 │ (9, 11)      3.24        0.0    5114.14         2127.16            0.0
#  110 │ (10, 11)     1.8         0.0    2103.45          874.666           0.0

# %% [markdown]
# `mlmnet_cv_summary` displays a table of the average mean-squared error and proportion of zero coefficients across the folds for each value of lambda. The optimal lambda might be the one that minimizes the mean-squared error (MSE), or can be chosen based on a pre-determined proportion of zeros that is desired in the coefficient estimates.

# %% [markdown]
# The `lambda_min` function returns the summary information for the lambdas that correspond to the minimum average test MSE across folds and the MSE that is one standard error greater.

# %%
lambda_min(estCVObjs)
# Out:
# 2×6 DataFrame
#  Row │ Name           Index   Lambda   Alpha    AvgMSE   AvgPropZero
#      │ String         Tuple…  Float64  Float64  Float64  Float64
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ (𝜆, 𝛼)_min     (2, 1)  198.359      1.0  34.6111        0.966
#    2 │ (𝜆, 𝛼)_min1se  (1, 1)  357.047      1.0  38.9581        1.0
